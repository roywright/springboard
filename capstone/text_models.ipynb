# %% [markdown]
# # Attempts at Classifiers Derived from Yelp Reviews Text Data
# ## Loading text data:
# ### (See comments in code)

# %%
import pandas as pd
from numpy import nan
import numpy as np
import scipy.stats as stats
from datetime import datetime
from datetime import timedelta
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
violations = pd.read_pickle('data/violations_wtext.pkl')
violations = violations[[
        'date',            # Date of inspection 
        'delay',           # Days since last inspection
        'restaurant_id',   # Restaurant identifier
        '*', '**', '***',  # Number of violations at three severity levels
        'reviews',         # Aggregated text of all Yelp reviews from previous year
        'cool',            # Aggregated text of Yelp reviews voted "cool" by at least one user
        'funny',           # Aggregated text of Yelp reviews voted "funny" by at least one user
        'useful',          # Aggregated text of Yelp reviews voted "useful" by at least one user
        'tips'             # Aggregated text of all Yelp tips from previous year
    ]]
violations
# Out:
#             date  delay restaurant_id   *  **  ***  \
# 15836 2011-08-01    NaN      NbE1Bk3J   8   1    0
# 1401  2011-08-01    NaN      7RO5vjEq   7   1    0
# 25218 2011-08-01    NaN      V430D43B   1   0    2
# 34217 2011-08-01    NaN      Y1EmaVEw   7   0    1
# 27586 2011-08-01    NaN      6Wo2Nyo9  11   2    1
# 33235 2011-08-01    NaN      8x3zgYok   2   0    1
# 6368  2011-08-01    NaN      8x3zx2Ok   5   0    2
# 21033 2011-08-01    NaN      qN3gvnEA   5   0    1
# 21523 2011-08-01    NaN      VpoG57Er   1   0    0
# 6157  2011-08-01    NaN      dj3dlN39   1   0    2
# 3004  2011-08-01    NaN      8x3zQZEk   4   1    1
# 355   2011-08-01    NaN      nkOvRxOB   2   0    2
# 21824 2011-08-01    NaN      8xEx44E0   5   1    2
# 24574 2011-08-01    NaN      8x3zdNOk   2   1    0
# 32211 2011-08-01    NaN      6K3lj6Oz   3   0    0
# 21858 2011-08-01    NaN      KAoK283g   5   1    4
# 10741 2011-08-01    NaN      ZBEn6pEY   1   0    1
# 31048 2011-08-01    NaN      dj3d57o9   8   1    0
# 10989 2011-08-01    NaN      dj3dqNo9   3   1    0
# 7354  2011-08-02    NaN      N6OkkGOx   5   1    0
# 19115 2011-08-02    NaN      p038ZvOm   0   0    0
# 5379  2011-08-02    NaN      v5oJMA3B   4   0    0
# 34620 2011-08-02    NaN      Pk3wga3d   3   0    3
# 6858  2011-08-02    NaN      ydEjW23W   1   0    2
# 1267  2011-08-02    NaN      ZBEn02oY   4   0    0
# 6716  2011-08-02    NaN      JBEy6m38   2   0    3
# 21940 2011-08-02    NaN      rNo6gqO6   1   0    0
# 33447 2011-08-02    NaN      ZBEnraEY   3   0    1
# 8305  2011-08-02    NaN      7RO5wd3q   5   2    0
# 23759 2011-08-02    NaN      9JoP47o8   6   0    0
# ...          ...    ...           ...  ..  ..  ...
# 11296 2015-06-23  274.0      ydEjQ2OW   6   1    0
# 27508 2015-06-23  154.0      B1oXMDOV   6   0    2
# 21326 2015-06-23  182.0      WeEere3a   3   0    0
# 14713 2015-06-23  320.0      7RO56XEq   3   0    1
# 1479  2015-06-23    7.0      geEVRzEz   1   1    1
# 23630 2015-06-23  110.0      p038De3m   2   0    0
# 12454 2015-06-23  124.0      nkOvZZOB   2   0    0
# 765   2015-06-23   14.0      ydEjeOW0   4   1    0
# 18310 2015-06-23  508.0      we395l3k   2   0    0
# 2472  2015-06-23    8.0      xWoYGMEK   3   0    0
# 26525 2015-06-24   13.0      rJoQdL3V   4   0    0
# 17962 2015-06-24    7.0      6K3lB8Oz   2   0    1
# 33974 2015-06-24   15.0      nkOvWxEB   7   2    0
# 27806 2015-06-24  363.0      JBEyamE8   8   1    1
# 14030 2015-06-24    1.0      qN3gAYOA   5   1    3
# 2423  2015-06-24  442.0      XJ3r1bER   4   0    1
# 7875  2015-06-24  166.0      Y1EmNn3w   6   1    0
# 35221 2015-06-24   14.0      m0oW02OG   5   0    0
# 22714 2015-06-24   42.0      6K3lZqOz   0   0    2
# 19870 2015-06-24  329.0      we39KlOk   6   2    4
# 1924  2015-06-24  321.0      B1oX66EV   2   1    3
# 14533 2015-06-24    7.0      1m3MbpoB   5   0    1
# 5337  2015-06-24    7.0      njoZqQ3r   8   1    0
# 33931 2015-06-25  160.0      nkOv473B   0   0    0
# 20585 2015-06-25  134.0      Y1EmxWOw   6   0    3
# 30857 2015-06-25    7.0      8gOqY0O2   1   0    0
# 20620 2015-06-25    7.0      dj3dBLO9  13   1    3
# 24516 2015-06-25    7.0      eVOBda3j  11   0    1
# 33342 2015-06-25  120.0      nkOvkaEB   5   1    0
# 35387 2015-06-25  134.0      m0oWY1EG   9   0    3
#
#                                                  reviews  \
# 15836  Manger une pizza a pas chers c est la place qu...
# 1401   Buffet joints aren't usually where you go to g...
# 25218  Was told it was a 5 min wait for a table. They...
# 34217  Dropped in with a friend during one of their s...
# 27586
# 33235  I like Au Bon Pain very much.  Whether it's th...
# 6368   We stayed at this hotel for 3 nights for the f...
# 21033  It's a love/hate relationship. There are times...
# 21523
# 6157   Get the teriyaki chicken with EXTRA chicken!  ...
# 3004   Not again...why is it impossible to find good ...
# 355    For a small sushi bar/kiosk that is located in...
# 21824  After much waiting I had a chance to try Mul's...
# 24574  Pros:\n- cheap\n- delivers\n- nice people work...
# 32211  A good restaurant should maintain it's standar...
# 21858  BEST BREAKFAST/BRUNCH IN BOSTON..Let me put it...
# 10741  I really like this Dunkin Donuts because it is...
# 31048  taste is very good. Economic price but valuabl...
# 10989  I cam here twice during my stay in Boston.  Fe...
# 7354   Just ate here, and I would echo the feelings o...
# 19115  The Bus Stop is likeable and consistent.  The ...
# 5379   I wish I could give other rating symbols in ye...
# 34620  I enjoyed my Panini from this new sandwich sho...
# 6858   Um, not so much.  \n\nI liked you at first, bu...
# 1267   Was glad I made a reservation, since others wh...
# 6716   When I need a great salad full of veggies and ...
# 21940  The best slice for the price! AND NOW THEY DEL...
# 33447  Emack, you rock.  I mean, let's be honest here...
# 8305   My time in Miami taught me to find the best pl...
# 23759  This is one of my favorite places in Boston fo...
# ...                                                  ...
# 11296  I was not impressed with my sandwich this past...
# 27508  This place is so much better than its name sug...
# 21326  This place wreaks like a mixture of piss and w...
# 14713  I love this place they have great authentic fo...
# 1479   Gotta love Twin Donuts. Small business. Mad ch...
# 23630  So delicious it's silly how little you pay for...
# 12454  No Name had been recommended to me by a co-wor...
# 765    Great authentic Dominican food! Don't really g...
# 18310  Two nights in a row when the server/bartender ...
# 2472   Good chowder soup! I liked the taste and it wa...
# 26525  Great sushi... different styles of asian food:...
# 17962  Definitely check out this restaurant. Saraceno...
# 33974  I was visiting Boston a few weeks ago\nfor my ...
# 27806  I'll start with the good:  service was prompt,...
# 14030  Went here on Father's Day for lunch.  The serv...
# 2423   What a great find!  Stopped by for food truck ...
# 7875   Worst sushi I've had in years. The rice was fa...
# 35221  First time @ this location. They bombed it. Wa...
# 22714  Big fan of the atmosphere, cocktails, and vari...
# 19870  I was very excited to try out this place, but ...
# 1924   If you're hungry, don't want burnt food, and h...
# 14533  Gel lato crap..!   If you see this place just ...
# 5337   Great food lacking service. I went with the pa...
# 33931  Thanks to the team at Monumental for the most ...
# 20585  What has happened to this place?   When I live...
# 30857  I've been coming here for months and had no pr...
# 20620  Went for lunch.  Good casual food, good beer, ...
# 24516
# 33342  Pho Hoa is known for it's tasty broth and I co...
# 35387  This  food is flavorless  there were no vegeta...
#
#                                                     cool  \
# 15836  Their name is similar to another pizza shop in...
# 1401   Bad, bad, bad food. If you're marketed as a bu...
# 25218  We descended upon Florentine Cafe one chilly n...
# 34217  I liked the hot pot. They have a nice variety....
# 27586
# 33235  You know, it's a funny thing - I never even th...
# 6368   We stayed at this hotel for 3 nights for the f...
# 21033  It's always so crowed here during lunch time. ...
# 21523
# 6157
# 3004
# 355    Stick with the basics, nigiri and sashimi. The...
# 21824  After much waiting I had a chance to try Mul's...
# 24574  It's Chinese food in the North End.\n\nIt's no...
# 32211  *3.5 stars*\n\nThe best part about being from ...
# 21858  BEST BREAKFAST/BRUNCH IN BOSTON..Let me put it...
# 10741
# 31048  My fave chinese bbq in boston so far!:) good p...
# 10989  Found this place during a obsessive compulsive...
# 7354   Just ate here, and I would echo the feelings o...
# 19115  The Bus Stop is likeable and consistent.  The ...
# 5379
# 34620
# 6858
# 1267   This place has the most spectacular view of th...
# 6716   So I suck at salad bars.  My eyes are always b...
# 21940  The best slice for the price! AND NOW THEY DEL...
# 33447
# 8305   My time in Miami taught me to find the best pl...
# 23759  I went here for Restauarant Week and am so gla...
# ...                                                  ...
# 11296
# 27508  This is my favorite restaurant because their s...
# 21326
# 14713  Really a great surprise while trying to decide...
# 1479   The honey dipped donut is SO GOOD and I'm not ...
# 23630  Got the lamb/beef shawarma and ordered it spic...
# 12454  Was in boston for a conference, a rainy cold M...
# 765
# 18310  I wish Yelp would allow no stars. This place h...
# 2472   Quick review for out-of-towners (of which, I a...
# 26525
# 17962  Limp salad, mediocre shrimp alla luciana.  The...
# 33974  I always have a great time when I come here BU...
# 27806
# 14030  Make a reservation, this place gets very busy ...
# 2423
# 7875   This place is about a 3 for the food and close...
# 35221             Applebees is amazing, get the 2 for 20
# 22714  Lovely restaurant!  Very cute restaurant/bar w...
# 19870  It was a rainy afternoon in Boston on the day ...
# 1924
# 14533
# 5337   Heaven is for real and it's at Mare Oyster Bar...
# 33931  I put in a special order for cider doughnuts t...
# 20585
# 30857
# 20620  stopped by last night to grab a quick mug of s...
# 24516
# 33342  Pho is still consistently good, special pho is...
# 35387
#
#                                                    funny  \
# 15836  This place is Trouble with a capital T.  Every...
# 1401   The buffet is right there in the window.  Look...
# 25218  Good place to take a date or dine with friends...
# 34217  I came here with my family on Columbus Day. I ...
# 27586
# 33235  When I mention Au Bon Pain, I EMPHASIZE THE PA...
# 6368   This hotel is prime property. I mean if you co...
# 21033  I've been here twice now.\nThe first time I wa...
# 21523
# 6157
# 3004
# 355
# 21824  After much waiting I had a chance to try Mul's...
# 24574
# 32211  *3.5 stars*\n\nThe best part about being from ...
# 21858  Great place! Music is a little loud so don't l...
# 10741
# 31048  I usually get the combo roast pork + BBQ pork....
# 10989  Found this place during a obsessive compulsive...
# 7354   This is one of those places where I have been ...
# 19115
# 5379   I wish I could give other rating symbols in ye...
# 34620  Can we get some caffeine in these people?!? \n...
# 6858
# 1267   Walking into Anthony's Pier 4 is like walking ...
# 6716   So I suck at salad bars.  My eyes are always b...
# 21940
# 33447  Emack, you rock.  I mean, let's be honest here...
# 8305   I've struggled for almost a week about writing...
# 23759  I went here for Restauarant Week and am so gla...
# ...                                                  ...
# 11296
# 27508  Location: Conveniently located on Centre St in...
# 21326
# 14713  You don't know how much it kills me that I can...
# 1479   The honey dipped donut is SO GOOD and I'm not ...
# 23630  The bessssst. If I could swear, here I'd add a...
# 12454  Worst service ever, my girlfriend and i went t...
# 765
# 18310  I wish Yelp would allow no stars. This place h...
# 2472   I was a fool to think lobster roll was just a ...
# 26525
# 17962  Limp salad, mediocre shrimp alla luciana.  The...
# 33974  I always have a great time when I come here BU...
# 27806
# 14030  I used to love this place.  Came back a year l...
# 2423
# 7875   Worst sushi I've had in years. The rice was fa...
# 35221             Applebees is amazing, get the 2 for 20
# 22714  We were looking for a place that was close to ...
# 19870  It was a rainy afternoon in Boston on the day ...
# 1924
# 14533  Meh. Doesn't taste anything like real gelato. ...
# 5337
# 33931  I write you from a Monumental Cupcakes induced...
# 20585  What has happened to this place?   When I live...
# 30857  I will forever rate all Chipotles with 5 stars...
# 20620  My friends and I went here yesterday during a ...
# 24516
# 33342  Pho is still consistently good, special pho is...
# 35387
#
#                                                   useful  \
# 15836  This place is Trouble with a capital T.  Every...
# 1401   A friend told me that there was all-you-can-ea...
# 25218  We descended upon Florentine Cafe one chilly n...
# 34217  Dropped in with a friend during one of their s...
# 27586
# 33235  When I mention Au Bon Pain, I EMPHASIZE THE PA...
# 6368   Great location \nService was good\n\nWe were "...
# 21033  It's always so crowed here during lunch time. ...
# 21523
# 6157
# 3004   This place is in my neighborhood and is always...
# 355    For a small sushi bar/kiosk that is located in...
# 21824  Some of the best diner bacon I have ever had. ...
# 24574  It's Chinese food in the North End.\n\nIt's no...
# 32211  *3.5 stars*\n\nThe best part about being from ...
# 21858  BEST BREAKFAST/BRUNCH IN BOSTON..Let me put it...
# 10741
# 31048  taste is very good. Economic price but valuabl...
# 10989  I've been to Charley's for brunch and dinner n...
# 7354
# 19115
# 5379
# 34620  I enjoyed my Panini from this new sandwich sho...
# 6858   Um, not so much.  \n\nI liked you at first, bu...
# 1267   i've heard a lot about this place - i guess it...
# 6716   Without a doubt, one of my favorite places for...
# 21940
# 33447  Emack, you rock.  I mean, let's be honest here...
# 8305   I've struggled for almost a week about writing...
# 23759  I went here for Restauarant Week and am so gla...
# ...                                                  ...
# 11296
# 27508  This is my favorite restaurant because their s...
# 21326
# 14713  You don't know how much it kills me that I can...
# 1479   Gotta love Twin Donuts. Small business. Mad ch...
# 23630  So delicious it's silly how little you pay for...
# 12454  No Name had been recommended to me by a co-wor...
# 765    Great authentic Dominican food! Don't really g...
# 18310  Two nights in a row when the server/bartender ...
# 2472   I was a fool to think lobster roll was just a ...
# 26525
# 17962  Food was great, waiter was this old dude who o...
# 33974  Knowing nothing about Stats, I won a $100 gift...
# 27806
# 14030  Just alright. Came here twice, once for dinner...
# 2423   I had been looking forward to trying M&M ribs ...
# 7875   This place is about a 3 for the food and close...
# 35221  Applebees is amazing, get the 2 for 20 We came...
# 22714  We were looking for a place that was close to ...
# 19870  I was very excited to try out this place, but ...
# 1924   If you're hungry, don't want burnt food, and h...
# 14533  Gel lato crap..!   If you see this place just ...
# 5337   Heaven is for real and it's at Mare Oyster Bar...
# 33931  Thanks to the team at Monumental for the most ...
# 20585  What has happened to this place?   When I live...
# 30857  This location needs some help. Came in at lunc...
# 20620  Went for lunch.  Good casual food, good beer, ...
# 24516
# 33342  Let's start off with pho, it is good but doesn...
# 35387
#
#                                                     tips
# 15836  Potato pizza rocks my socks Love the food & be...
# 1401   Not the very best Korean but they're the only ...
# 25218  Lobster ravioli is a house fav. bartenders are...
# 34217  Make reservations Awesome food, friendly wait ...
# 27586
# 33235
# 6368   Suad is here!!! Champions for NCAA action... v...
# 21033  Cash only! But so damned worth it. The owner c...
# 21523
# 6157
# 3004
# 355
# 21824  They have the best hash.. Nice old school Dine...
# 24574  Always double check your order before you leav...
# 32211  Fig & prosciutto pizza with goat cheese and ca...
# 21858  variety galore! and a 15min pleasant walk from...
# 10741              Parking lot is almost always crowded.
# 31048  Get the spicy beef with rice and make sure Ste...
# 10989        Thank god for heat lamps Amazing sangria!!!
# 7354             College combo is a steal and delicious!
# 19115         Go Bruins!!! Crowded when the Bruins play.
# 5379                                      Fast delivery!
# 34620
# 6858
# 1267   Grab a drink at the bar and you'll get a round...
# 6716
# 21940
# 33447
# 8305   U have to try the mussels and the peel shrimp ...
# 23759                      Birthday Breakfast. Brunching
# ...                                                  ...
# 11296  Curbside delivery available just call (617) 56...
# 27508  Be brave and try a bibimbap! Happy Birthday Ph...
# 21326
# 14713  My 1st time trying spinach pie and it was deli...
# 1479   Donuts mmmmm I always get my egg and cheese cr...
# 23630  Pay cash. Get a free drink I am big fan of the...
# 12454  Don't bother. Bad service bad food and bad dec...
# 765
# 18310  Front desk is super helpful. They can send / r...
# 2472   The lobster Mac and cheese is out of this worl...
# 26525         The pad Thai is amazing and a great price.
# 17962  Dinner Do not get the meatballs they taste lik...
# 33974                     Hardo bar 101 on the weekends.
# 27806
# 14030  Great service.  Good food. What more can u ask...
# 2423
# 7875   Really need to fix the timing for pick-up. Alw...
# 35221  Super hungry with hubster For a chain restaura...
# 22714  Our server seemed really friendly! Just ask wh...
# 19870  Everything is awesome here Great service, amaz...
# 1924
# 14533  There is no sign that says cash only, and its ...
# 5337   Walk it is lovely there and back Great food an...
# 33931
# 20585  Blue star is awesome place to eat for a feel o...
# 30857  Chipotle is my fav! Their quality and taste ma...
# 20620
# 24516
# 33342  Get the Pho Hoa Hoa Hoa :) Cheap with the amou...
# 35387
#
# [17557 rows x 11 columns]

# %%
violations = violations[violations.delay > 14]

# %% [markdown]
# ## Classifier Attempts:
# ### Naive Bayes using CountVectorizer features

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cross_validation import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from sklearn.grid_search import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import TruncatedSVD

# %%
vectorizer = CountVectorizer(
    ngram_range = (1,2), 
    stop_words = 'english'
)

X = violations.reviews
y = (violations['*'] + violations['**'] + violations['***'] > 0).values.astype(np.int)

Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, train_size=.8, stratify = y)
Xtrain = vectorizer.fit_transform(Xtrain)

clf = MultinomialNB(alpha = 50)
clf.fit(Xtrain, ytrain)
print(
    'Training score: ' + str(clf.score(Xtrain, ytrain)) + '\n' +
    'Testing score: ' + str(clf.score(vectorizer.transform(Xtest), ytest)) + '\n' +
    'Proportion of inspections in test set that failed: ' + str(sum(ytest)/len(ytest))
    )
# Out:
# Training score: 0.656768672199
# Testing score: 0.656817003629
# Proportion of inspections in test set that failed: 0.656817003629

# %% [markdown]
# ### Stochastic gradient descent using TF-IDF features

# %%
vectorizer = TfidfVectorizer(
    ngram_range = (1,2), 
    stop_words = 'english'
)

X = violations.reviews
y = (violations['*'] + violations['**'] + violations['***'] > 0).values.astype(np.int)

Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, train_size=.8, stratify = y)
Xtrain = vectorizer.fit_transform(Xtrain)

clf = SGDClassifier(n_jobs = -1)
clf.fit(Xtrain, ytrain)
print(
    'Training score: ' + str(clf.score(Xtrain, ytrain)) + '\n' +
    'Testing score: ' + str(clf.score(vectorizer.transform(Xtest), ytest)) + '\n' +
    'Proportion of inspections in test set that failed: ' + str(sum(ytest)/len(ytest))
    )
# Out:
# Training score: 0.834154564315
# Testing score: 0.637117677553
# Proportion of inspections in test set that failed: 0.656817003629

# %% [markdown]
# ### Random Forest using a selection of 1000 TF-IDF features

# %%
vectorizer = TfidfVectorizer(
    ngram_range = (1,2), 
    stop_words = 'english',
    max_features = 1000
)

X = violations.reviews
y = (violations['*'] + violations['**'] + violations['***'] > 0).values.astype(np.int)

Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, train_size=.8, stratify = y)
Xtrain = vectorizer.fit_transform(Xtrain)

gs = GridSearchCV(
        estimator = RandomForestClassifier(n_estimators = 500),
        param_grid = {
            'min_samples_leaf' : np.arange(1, 30, 3),
            'max_features' : np.arange(10, 40, 5)
        },
        n_jobs = -1
)
gs.fit(Xtrain, ytrain)
clf = gs.best_estimator_

print(
    'Training score: ' + str(clf.score(Xtrain, ytrain)) + '\n' +
    'Testing score: ' + str(clf.score(vectorizer.transform(Xtest), ytest)) + '\n' +
    'Proportion of inspections in test set that failed: ' + str(sum(ytest)/len(ytest))
    )
# Out:
# Training score: 0.772821576763
# Testing score: 0.666666666667
# Proportion of inspections in test set that failed: 0.656817003629

# %% [markdown]
# ### SVM using a selection of 1000 TF-IDF features

# %%
vectorizer = TfidfVectorizer(
    ngram_range = (1,2), 
    stop_words = 'english',
    max_features = 1000
)

X = violations.reviews
y = (violations['*'] + violations['**'] + violations['***'] > 0).values.astype(np.int)

Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, train_size=.8, stratify = y)
Xtrain = vectorizer.fit_transform(Xtrain)

gs = GridSearchCV(
        estimator = SVC(probability = True),
        param_grid = {
            'C' : np.logspace(-3, 2, 6),
            'gamma' : np.logspace(-2, 0, 5)
        },
        n_jobs = -1
)
gs.fit(Xtrain, ytrain)
clf = gs.best_estimator_

print(
    'Training score: ' + str(clf.score(Xtrain, ytrain)) + '\n' +
    'Testing score: ' + str(clf.score(vectorizer.transform(Xtest), ytest)) + '\n' +
    'Proportion of inspections in test set that failed: ' + str(sum(ytest)/len(ytest))
    )
# Out:
# Training score: 0.747406639004
# Testing score: 0.662519440124
# Proportion of inspections in test set that failed: 0.656817003629

# %% [markdown]
# ### SVM using *all* TF-IDF features, but reduced to 100 dimensions

# %%
vectorizer = TfidfVectorizer(
    ngram_range = (1,2), 
    stop_words = 'english',
)
svd = TruncatedSVD(n_components = 100)

X = violations.reviews
y = (violations['*'] + violations['**'] + violations['***'] > 0).values.astype(np.int)

Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, train_size=.8, stratify = y)
Xtrain = vectorizer.fit_transform(Xtrain)
Xtrain = svd.fit_transform(Xtrain)

gs = GridSearchCV(
        estimator = SVC(probability = True),
        param_grid = {
            'C' : np.logspace(-3, 2, 6),
            'gamma' : np.logspace(-2, 0, 5)
        },
        n_jobs = -1
)
gs.fit(Xtrain, ytrain)
clf = gs.best_estimator_

print(
    'Training score: ' + str(clf.score(Xtrain, ytrain)) + '\n' +
    'Testing score: ' + str(clf.score(svd.transform(vectorizer.transform(Xtest)), ytest)) + '\n' +
    'Proportion of inspections in test set that failed: ' + str(sum(ytest)/len(ytest))
    )
