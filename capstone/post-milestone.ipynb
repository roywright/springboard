# %% [markdown]
# # Predicting Health Code Violations in Boston
# ### Capstone Milestone Report
# Roy Wright
# June 21, 2016
#
#
# ## The Problem
#
# We want to find restaurants that are likely to fail an unannounced health inspection &mdash; that is, we will estimate the probability that a health code violation would be found at a given food service establishment, if it were chosen to be inspected, without prior notice, right now.
#
#
# ## The Client
#
# The City of Boston, like many others, conducts health inspections of food service establishments in a largely random pattern of visits. With a model for predicting where and when health code violations might be expected, the inspections can be carried out in a targeted way. This could make more efficient use of inspectors' time and, more importantly, increase the chances of detecting violations.
#
# ## Datasets
# ### Health Inspections
# Detailed records of health inspections throughout Boston, from 2006 to present, can be obtained from [data.cityofboston.gov](https://data.cityofboston.gov/Health/Food-Establishment-Inspections/qndu-wx8w). Each inspection record includes the following pieces of information, among others:
# * Food service establishment's name
# * Category and type
#  - category "FS" stands for "Eating & Drinking"
#  - category "FT" stands for "Eating & Drinking w/ Take Out"
#  - category "MFW" stands for "Mobile Food Walk On"
#  - category "RF" stands for "Retail Food"
# * The result of the inspection
#  - "HE_Fail" when an establishment's first inspection (or first yearly inspection) is unsatisfactory
#  - "HE_FailExt" when an establishment is reinspected within a few weeks after a failure, and fails again
#  - "HE_Pass" when an establishment passes an inspection with no violations (either its first yearly inspection or a reinspection a few weeks after failure)
#  - "HE_Filed" for the first inspection of an opening establishment
#  - other result codes are much less common
# * The date of the inspection
# * Summary and description of each violation found, along with its severity, measured as \* or \*\* or \*\*\*
# * Written comments
# * Business address
# * Latitude/longitude coordinates (sometimes)
#
# Below, we load the data and make the following adjustments:
# * Cut off any records before August 1, 2011, because one of our other datasets does not extend back farther than this
# * Separate the latitude/longitude coordinates for later use
# * Process address information into a form that could more easily be used to look up latitude/longitude coordinates where they are missing
#
# A portion of some randomly-selected lines of the inspections data is shown.

# %%
import pandas as pd
from numpy import nan
import numpy as np
import scipy.stats as stats
from datetime import datetime
from datetime import timedelta
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
inspections = pd.read_csv(
    'data/Food_Establishment_Inspections.csv', 
    usecols = ['BusinessName', 'LICENSECAT',
       'DESCRIPT', 'RESULT', 'RESULTDTTM', 'Violation', 'ViolLevel',
       'ViolDesc', 'VIOLDTTM', 'ViolStatus', 'StatusDate', 'Comments', 'Address', 'City', 'State', 'Zip', 'Location'
    ],
    parse_dates = ['RESULTDTTM', 'VIOLDTTM', 'StatusDate'], 
    infer_datetime_format = True
)
inspections.columns = [
    'name',           # business name
    'category',       # business category ("FS", "FT", "RS", or "MFW")
    'type',           # more verbal description of business category 
    'result',         # result of the inspection (12 different possibilities)
    'result_date',    # date of inspection
    'violation',      # code for violation type
    'level',          # violation severity (can be * or ** or ***)
    'description',    # verbal description of violation
    'violation_date', # generally (or always?) the same as result_date
    'status',         # simply pass or fail
    'status_date',    # generally a day or so later than result_date, but often not given
    'comments',       # free-form text comments
    'address',
    'city',
    'state',
    'zip',
    'location'        # (latitude, longitude)
]
inspections['result_date'] = inspections.result_date.apply(lambda x: x.date())
inspections = inspections[
    (inspections.result_date.astype(str) >= '2011-08-01') 
]
inspections['location'] = inspections.location.str.strip('()')
inspections[['latitude','longitude']] = inspections['location'].apply(lambda x: pd.Series(str(x).split(',')))
inspections['latitude'] = pd.to_numeric(inspections.latitude, errors='coerce')
inspections['longitude'] = pd.to_numeric(inspections.longitude, errors='coerce')
inspections[['address']] = (
    inspections.address.fillna(inspections.name) + ', ' + inspections.city.fillna('Boston') + ', ' 
    + inspections.state.fillna('MA') + (' 0'+inspections.zip.fillna(0).astype(int).astype(str)).replace(' 00','')
)
inspections = inspections.drop(['city', 'state', 'zip', 'location'], 1)
inspections.sample(8)[['name', 'category', 'type', 'result', 'result_date', 'level', 'description', 'comments']]
# Out:
#                                        name category  \
# 300764                          CAFE PODIMA       FT
# 326494  SHERATON BOSTON (APROPOS/R.S./CAFE)       FS
# 179013           Brick House Pizza & Grille       FT
# 303396                  SAME OLD PLACE INC.       FS
# 233731                 Lilly's Pasta & Subs       FT
# 169317                       CHECKMATE CAFE       FT
# 303609                      Boston Shawarma       FS
# 403337                          BEE'S KNEES       RF
#
#                                  type    result result_date level  \
# 300764  Eating & Drinking w/ Take Out   HE_Pass  2016-01-21     *
# 326494              Eating & Drinking   HE_Fail  2016-02-11     *
# 179013  Eating & Drinking w/ Take Out  HE_Filed  2012-04-03     *
# 303396              Eating & Drinking   HE_Fail  2013-09-03     *
# 233731  Eating & Drinking w/ Take Out   HE_Pass  2012-02-10     *
# 169317  Eating & Drinking w/ Take Out   HE_Pass  2015-08-20     *
# 303609              Eating & Drinking  HE_Filed  2012-04-04     *
# 403337                    Retail Food   HE_Pass  2015-08-24    **
#
#                                    description  \
# 300764    Hand Cleaner  Drying  Tissue Signage
# 326494                         Food Protection
# 179013            Food Contact Surfaces Design
# 303396            Clean Cloths  Hair Restraint
# 233731                   Food Container Labels
# 169317          Wiping Cloths  Clean  Sanitize
# 303609  Improper Storage of Re-usable Utensils
# 403337               Insects  Rodents  Animals
#
#                                                  comments
# 300764  No paper towel dispenser at front counter hand...
# 326494  Observed raw shell eggs stored with deli slice...
# 179013  Plastic containers being used to dispense flow...
# 303396                                                NaN
# 233731  Provide labels for all food containers and sua...
# 169317  4-101.16 Provide commercial grade scrubber for...
# 303609  store all pots and pans upside down to reduce ...
# 403337  Remove heavy fly activity at the dumpster area...

# %% [markdown]
# ### Condensed Violations Records
# [Yelp.com](https://www.yelp.com/dataset_challenge/drivendata) published academic datasets for the 2015 "Keeping it Fresh: Predict Restaurant Inspections" contest, hosted by [DrivenData.org](https://www.drivendata.org/competitions/5/page/17/).
#
# At the heart of these datasets is a list of inspection results. Each row gives the inspection date, a "restaurant ID" number for the establishment inspected, and tallies of the violations found at each severity level (\*, \*\*, and \*\*\*). Another dataset gives a summary of Yelp-provided information for each business, including its name, address, "Yelp ID" number (which is distinct from its "restaurant ID"), number of Yelp reviews available, average rating, and latitude/longitude coordinates. Lastly, a table is provided for matching Yelp ID's to restaurant ID's.
#
# Below, we load these datasets. Then, after a slight reshaping of the ID matching table, we use that table to combine the other datasets into one. As before, we cut off any records before August 1, 2011. A few randomly-selected lines of the combined dataset is shown.

# %%
violations = pd.read_csv(
    'data/AllViolations.csv', 
    parse_dates = ['date'], 
    infer_datetime_format = True,
    index_col = 0
)

# %%
import json
from pandas.io.json import json_normalize

with open('data/yelp_academic_dataset_business.json', 'r') as f:
    data = f.readlines()
data = map(lambda x: x.rstrip(), data)
data_json_str = '[' + (',').join(data) + ']'

business = pd.read_json(data_json_str)
business = business[[
    'name',
    'full_address',
    'city',
    'business_id',
    'review_count', 
    'stars',
    'latitude',
    'longitude'
]]
business.columns = [
    'name',     
    'address',
    'city',
    'yelp_id',
    'reviews',
    'rating',
    'latitude',
    'longitude'
]

# %reset_selective -f data_json_str

# %%
idtable = pd.read_csv(
    'data/restaurant_ids_to_yelp_ids.csv'
)
idtable = pd.concat([
        idtable[['restaurant_id','yelp_id_0']].rename(columns = {'yelp_id_0':'yelp_id'}),
        idtable[idtable.yelp_id_1.notnull()][['restaurant_id','yelp_id_1']].rename(columns = {'yelp_id_1':'yelp_id'}),
        idtable[idtable.yelp_id_2.notnull()][['restaurant_id','yelp_id_2']].rename(columns = {'yelp_id_2':'yelp_id'}),
        idtable[idtable.yelp_id_3.notnull()][['restaurant_id','yelp_id_3']].rename(columns = {'yelp_id_3':'yelp_id'})
], ignore_index = True)

# %%
violations = violations.merge(
    idtable, 
    on = 'restaurant_id'
).merge(
    business, 
    on = 'yelp_id'
).drop(['yelp_id', 'address', 'city'], 1)
violations = violations[violations.date >= '2011-08-01'].sort_values('date')
violations.sample(5)
# Out:
#             date restaurant_id  *  **  ***                name  reviews  \
# 5911  2014-07-17      1m3M8pEB  0   0    0   The Warren Tavern      211
# 7062  2015-05-19      1m3MJDoB  8   0    3  Spring Street Cafe       33
# 35400 2013-01-18      wmo7R73q  8   0    0   Derne Street Deli       31
# 18774 2012-12-30      Y1EmQ7Ew  0   0    0  Toscano Restaurant      294
# 13428 2013-01-16      XJ3rZZ3R  0   0    0           Starbucks       15
#
#        rating   latitude  longitude
# 5911      4.0  42.374226 -71.063110
# 7062      3.0  42.272129 -71.171897
# 35400     4.0  42.359477 -71.063477
# 18774     4.0  42.357408 -71.069847
# 13428     3.0  42.348542 -71.082583

# %% [markdown]
# ### Comparison of the Inspections Datasets

# %% [markdown]
# We have two separate datasets that provide records of past health inspections. To compare these datasets, let's take a look at the contents of each one for a single day. Below, we display the contents for August 12, 2014. This date is chosen mostly arbitrarily.

# %%
inspections[inspections.result_date.astype(str) == '2014-08-12'][[
        'name', 'category', 'result', 'result_date', 'level', 'description', 'comments','latitude','longitude'
    ]].sort_values('name')
# Out:
#                                                   name category    result  \
# 363499                                 A C Farm Market       RF   HE_Pass
# 393035                                 A C Farm Market       RF   HE_Pass
# 367015                                 A C Farm Market       RF   HE_Pass
# 375200                                 A C Farm Market       RF   HE_Pass
# 377256                                 A C Farm Market       RF   HE_Pass
# 144937                         Choice's by Au Bon Pain       FT   HE_Fail
# 149089                         Choice's by Au Bon Pain       FT   HE_Fail
# 148702                         Choice's by Au Bon Pain       FT   HE_Fail
# 144049                         Choice's by Au Bon Pain       FT   HE_Fail
# 146524                         Choice's by Au Bon Pain       FT   HE_Fail
# 382716                                     City Sports       RF   HE_Fail
# 380745                                     City Sports       RF   HE_Fail
# 374172                               Convenient Corner       RF  HE_Filed
# 178195                         DUNKIN DONUTS(FRANKLIN)       FT   HE_Pass
# 288906                                         Foumami       FT   HE_Pass
# 293642                                      Great Chef       FT   HE_Pass
# 291988                                      Great Chef       FT   HE_Pass
# 292186                                      Great Chef       FT   HE_Pass
# 293742                                      Great Chef       FT   HE_Pass
# 293957                                      Great Chef       FT   HE_Pass
# 294731                                      Great Chef       FT   HE_Pass
# 294677                                      Great Chef       FT   HE_Pass
# 294069                                      Great Chef       FT   HE_Pass
# 294624                                      Great Chef       FT   HE_Pass
# 143488                     Harvard Stadium Stand No. 2       FT   HE_Pass
# 293939                                          KANTIN       FT   HE_Fail
# 293454                                          KANTIN       FT   HE_Fail
# 293284                                          KANTIN       FT   HE_Fail
# 294890                                          KANTIN       FT   HE_Fail
# 46144                                LOLLICUP TEA ZONE       FT   HE_Fail
# ...                                                ...      ...       ...
# 295245                            SOUTH BOSTON CHINESE       FT   HE_Pass
# 294922                            SOUTH BOSTON CHINESE       FT   HE_Pass
# 294477                            SOUTH BOSTON CHINESE       FT   HE_Pass
# 63410                             Samurai Kuang Eatery       FT   HE_Pass
# 63352                             Samurai Kuang Eatery       FT   HE_Pass
# 63204                             Samurai Kuang Eatery       FT   HE_Pass
# 63148                             Samurai Kuang Eatery       FT   HE_Pass
# 63080                             Samurai Kuang Eatery       FT   HE_Pass
# 36696              Savory Food Truck No.  3 (P-33-235)      MFW  HE_Filed
# 1736                              Shanghai Social Club       FS   HE_Pass
# 46029                             Shanghai Social Club       FS   HE_Pass
# 44837                             Shanghai Social Club       FS   HE_Pass
# 4357                              Shanghai Social Club       FS   HE_Pass
# 404978                      Shaw's Supermarket No. 586       RF   HE_Fail
# 391905                      Shaw's Supermarket No. 586       RF   HE_Fail
# 368395                      Shaw's Supermarket No. 586       RF   HE_Fail
# 372583                      Shaw's Supermarket No. 586       RF   HE_Fail
# 386183                      Shaw's Supermarket No. 586       RF   HE_Fail
# 379212                      Shaw's Supermarket No. 586       RF   HE_Fail
# 381183                      Shaw's Supermarket No. 586       RF   HE_Fail
# 160692                        Squeeze Cafe & Juice Bar       FT  HE_Filed
# 77241   THE CATERED AFFAIR @ BOS. PUBLIC LIBRARY(T.O.)       FT   HE_Fail
# 77182   THE CATERED AFFAIR @ BOS. PUBLIC LIBRARY(T.O.)       FT   HE_Fail
# 121337      THE CATERED AFFAIR @ BOSTON PUBLIC LIBRARY       FS   HE_Fail
# 120538      THE CATERED AFFAIR @ BOSTON PUBLIC LIBRARY       FS   HE_Fail
# 119406      THE CATERED AFFAIR @ BOSTON PUBLIC LIBRARY       FS   HE_Fail
# 150238                              WORLD TRADE CENTER       FT   HE_Fail
# 66774                               WORLD TRADE CENTER       FT   HE_Fail
# 61345                               WORLD TRADE CENTER       FT   HE_Fail
# 64401                               WORLD TRADE CENTER       FT   HE_Fail
#
#        result_date level                                    description  \
# 363499  2014-08-12     *                      Non-Food Contact Surfaces
# 393035  2014-08-12     *                                Food Protection
# 367015  2014-08-12    **                      Insects  Rodents  Animals
# 375200  2014-08-12     *                          Dishwashng Facilities
# 377256  2014-08-12     *                          Food Container Labels
# 144937  2014-08-12     *                      Non-Food Contact Surfaces
# 149089  2014-08-12   ***                                   Cold Holding
# 148702  2014-08-12     *                         Equipment Thermometers
# 144049  2014-08-12     *                Non-Food Contact Surfaces Clean
# 146524  2014-08-12     *                 Improper Maintenance of Floors
# 382716  2014-08-12     *           Hand Cleaner  Drying  Tissue Signage
# 380745  2014-08-12     *                       Installed and Maintained
# 374172  2014-08-12     *                Non-Food Contact Surfaces Clean
# 178195  2014-08-12   NaN                                            NaN
# 288906  2014-08-12   NaN                                            NaN
# 293642  2014-08-12     *                         Equipment Thermometers
# 291988  2014-08-12     *                           Soiled Linen Storage
# 292186  2014-08-12     *         Improper Maintenance of Walls/Ceilings
# 293742  2014-08-12     *                 Wiping Cloths  Clean  Sanitize
# 293957  2014-08-12     *                                Food Protection
# 294731  2014-08-12     *                      Non-Food Contact Surfaces
# 294677  2014-08-12     *                Non-Food Contact Surfaces Clean
# 294069  2014-08-12     *                                Food Protection
# 294624  2014-08-12     *                Non-Food Contact Surfaces Clean
# 143488  2014-08-12   NaN                                            NaN
# 293939  2014-08-12   ***                          PIC Performing Duties
# 293454  2014-08-12     *                       Installed and Maintained
# 293284  2014-08-12     *                      Non-Food Contact Surfaces
# 294890  2014-08-12     *                            Premises Maintained
# 46144   2014-08-12   ***    Separation  Segregation Cross Contamination
# ...            ...   ...                                            ...
# 295245  2014-08-12     *           Hand Cleaner  Drying  Tissue Signage
# 294922  2014-08-12     *                Non-Food Contact Surfaces Clean
# 294477  2014-08-12     *                      Non-Food Contact Surfaces
# 63410   2014-08-12   ***                                   Cold Holding
# 63352   2014-08-12     *                         Equipment Thermometers
# 63204   2014-08-12     *                 Improper Maintenance of Floors
# 63148   2014-08-12     *                      Non-Food Contact Surfaces
# 63080   2014-08-12     *         Improper Maintenance of Walls/Ceilings
# 36696   2014-08-12     *        Adequate Number  Frequency Vermin Proof
# 1736    2014-08-12     *                            Premises Maintained
# 46029   2014-08-12     *         Improper Maintenance of Walls/Ceilings
# 44837   2014-08-12   ***                           Labeled  Common Name
# 4357    2014-08-12    **                      Insects  Rodents  Animals
# 404978  2014-08-12     *                   Food Contact Surfaces Design
# 391905  2014-08-12     *                Non-Food Contact Surfaces Clean
# 368395  2014-08-12     *                 Improper Maintenance of Floors
# 372583  2014-08-12     *         Improper Maintenance of Walls/Ceilings
# 386183  2014-08-12     *                       Installed and Maintained
# 379212  2014-08-12     *                      Non-Food Contact Surfaces
# 381183  2014-08-12   ***                                   Cold Holding
# 160692  2014-08-12     *                         Equipment Thermometers
# 77241   2014-08-12     *         Improper Maintenance of Walls/Ceilings
# 77182   2014-08-12     *                      Non-Food Contact Surfaces
# 121337  2014-08-12     *           Hand Cleaner  Drying  Tissue Signage
# 120538  2014-08-12     *         Improper Maintenance of Walls/Ceilings
# 119406  2014-08-12     *                Fixture's not properly shielded
# 150238  2014-08-12     *  Walls/Ceilings Designed Constructed Installed
# 66774   2014-08-12     *          Floors Designed Constructed Installed
# 61345   2014-08-12     *                      Non-Food Contact Surfaces
# 64401   2014-08-12     *                            Premises Maintained
#
#                                                  comments   latitude  \
# 363499            Repair rusty shelving below prep table.  42.302302
# 393035  Discontinue store  vegetables in stagnant wate...  42.302302
# 367015  Evidence of fruit flies provide exterminators ...  42.302302
# 375200                        Replace missing sink plugs.  42.302302
# 377256             Provide labels for all packaged foods.  42.302302
# 144937  bakery/replace worn door gasket to 1 door reac...        NaN
# 149089  salad bar/carrot and raisin salad 49 degrees/c...        NaN
# 148702  front line/ 2 door drawer/provide internal the...        NaN
# 144049                  salad bar/clean interior cabinets        NaN
# 146524  replace damaged floor tile in front of proof b...        NaN
# 382716  restroom/provide employee must wash hands signage  42.350722
# 380745         repair hot water faucet handle in restroom  42.350722
# 374172  Bottles of juice and sodas observed being stor...  42.292531
# 178195                                                NaN  42.356510
# 288906                                                NaN        NaN
# 293642      Provide visible thermometers where necessary.  42.379493
# 291988            Basement -Cover dirty laundry container  42.379493
# 292186                           Clean cooking vent hood.  42.379493
# 293742                    Keep wiping cloths in sanitizer  42.379493
# 293957   Elevate food containers 6" off floor in walk in.  42.379493
# 294731                         Defrost french fry freezer  42.379493
# 294677      Clean underside of shelving over prep tables.  42.379493
# 294069                 Cover all open foods in reach ins.  42.379493
# 294624              Clean and refinish rusted Can opener.  42.379493
# 143488                                                NaN        NaN
# 293939  The time as a public health control logs are n...  42.352411
# 293454  The cold water at the back handwash sink is no...  42.352411
# 293284  There is duct tape on the handle of the rice c...  42.352411
# 294890  There is excess clutter in the upstairs storag...  42.352411
# 46144   The raw chicken is stored above ready to eat t...  42.352411
# ...                                                   ...        ...
# 295245  Provide paper towels for ALL hands sinks in th...        NaN
# 294922              clean shelving inside walk in cooler.        NaN
# 294477  remove cardboard from shelf on cart near hans ...        NaN
# 63410   Sushi grade salmon 51F  White fish 50F / Provi...  42.355795
# 63352              Dish machine gauge is broken / Repair.  42.355795
# 63204   Floors under cookline  around handsink heavily...  42.355795
# 63148   Back door opened  without screen / Provide scr...  42.355795
# 63080   Hood vents with visible grease build up / Clea...  42.355795
# 36696                provide trash recepticle with cover.  42.362741
# 1736    There is a excess equipment underneath the old...  42.349820
# 46029   There are holes in the walls.  Repair. The bac...  42.349820
# 44837   Spray bottles are unlabeled.  Label spray bott...  42.349820
# 4357    The floor in the storage area is soiled with r...  42.349820
# 404978  Sponge being used at the 3 bay sink in the pro...  42.271930
# 391905  Interior of the chicken freezer near the rotis...  42.271930
# 368395  Floor under the storage cabinet near the rotti...  42.271930
# 372583  Portion of the wall in the meat walk-in cooler...  42.271930
# 386183  Pipe under the hand sink in the meat preparati...  42.271930
# 379212  Salad bar unit operating at around 50F. PIC (B...  42.271930
# 381183  All foods inside of the salad bar withg temper...  42.271930
# 160692  Temperature gauge on dish machine broken / Rep...  42.356135
# 77241               repair/remove flaking paint from wall  42.349231
# 77182   handsink/provide proper divider to sink 2 door...  42.349231
# 121337  hot line handsink/provide employee must wash h...  42.349231
# 120538  mop sink/replace damaged ceiling tile kitchen/...  42.349231
# 119406  hot line/provide proper light shields kitchen/...  42.349231
# 150238  replace stained and heavily soiled ceiling til...        NaN
# 66774   clean floor of paper goods storage room. also ...        NaN
# 61345   remove ice buildup from pipes inside walk i8n ...        NaN
# 64401   remove shoes from tops of lockers in both chan...        NaN
#
#         longitude
# 363499 -71.059800
# 393035 -71.059800
# 367015 -71.059800
# 375200 -71.059800
# 377256 -71.059800
# 144937        NaN
# 149089        NaN
# 148702        NaN
# 144049        NaN
# 146524        NaN
# 382716 -71.073709
# 380745 -71.073709
# 374172 -71.062241
# 178195 -71.053320
# 288906        NaN
# 293642 -71.027910
# 291988 -71.027910
# 292186 -71.027910
# 293742 -71.027910
# 293957 -71.027910
# 294731 -71.027910
# 294677 -71.027910
# 294069 -71.027910
# 294624 -71.027910
# 143488        NaN
# 293939 -71.125329
# 293454 -71.125329
# 293284 -71.125329
# 294890 -71.125329
# 46144  -71.125329
# ...           ...
# 295245        NaN
# 294922        NaN
# 294477        NaN
# 63410  -71.058451
# 63352  -71.058451
# 63204  -71.058451
# 63148  -71.058451
# 63080  -71.058451
# 36696  -71.066147
# 1736   -71.133420
# 46029  -71.133420
# 44837  -71.133420
# 4357   -71.133420
# 404978 -71.069700
# 391905 -71.069700
# 368395 -71.069700
# 372583 -71.069700
# 386183 -71.069700
# 379212 -71.069700
# 381183 -71.069700
# 160692 -71.054068
# 77241  -71.078658
# 77182  -71.078658
# 121337 -71.078658
# 120538 -71.078658
# 119406 -71.078658
# 150238        NaN
# 66774         NaN
# 61345         NaN
# 64401         NaN
#
# [110 rows x 9 columns]

# %%
violations[violations.date == '2014-08-12'].drop(['reviews','rating'], 1).sort_values('name')
# Out:
#             date restaurant_id   *  **  ***  \
# 8004  2014-08-12      we39j9ok   4   0    0
# 20155 2014-08-12      lnORdd3N   0   0    0
# 33990 2014-08-12      KAoK8ZOg   0   0    0
# 7757  2014-08-12      0ZEDGWOD   9   0    0
# 1423  2014-08-12      njoZ1D3r   3   0    1
# 2566  2014-08-12      eVOBLr3j   1   0    1
# 35075 2014-08-12      B1oXNlEV  11   1    3
# 25898 2014-08-12      B1oX4boV   4   0    1
# 28452 2014-08-12      8xExZeo0   4   1    1
#
#                                      name   latitude  longitude
# 8004                       Dunkin' Donuts  42.349264 -71.042474
# 20155                      Dunkin' Donuts  42.356527 -71.053353
# 33990                             Fóumami  42.356039 -71.053455
# 7757   Great Chef Chinese Food Day Square  42.379525 -71.027940
# 1423                               Kantin  42.352744 -71.125447
# 2566                             Lollicup  42.352444 -71.125403
# 35075                         Max Brenner  42.349491 -71.080588
# 25898                Samurai Kuang Eatery  42.355741 -71.058335
# 28452     South Boston Chinese Restaurant  42.336483 -71.047309

# %% [markdown]
# At a glance, we can see that the inspection records maintained by the City of Boston are more detailed than those provided by Yelp. It is easier to compare the two if we regroup the city's records in a way more like Yelp's version, as shown below.
#
# Note that some businesses present in the city's records do not appear in Yelp's data. In fact, it seems that no business of the "retail food" type appears in Yelp's data. On the other hand, every inspection listed in Yelp's data can be seen represented in the city's data, although not always clearly. For example, the first Dunkin' Donuts inspection listed above, with four 1-star violations and no 2- or 3-star violations, is listed at the bottom of the table below, with the name "WORLD TRADE CENTER" (which is actually the location of that particular Dunkin' Donuts). But aside from that, each of the other inspections shown above can be found without much difficulty in the table below.

# %%
inspections[
    inspections.result_date.astype(str) == '2014-08-12'\
].fillna('none').groupby([
        'name','level','result','type'
    ]).count()[['status']]
# Out:
#                                                                                                status
# name                                           level result     type
# A C Farm Market                                *     HE_Pass    Retail Food                         4
#                                                **    HE_Pass    Retail Food                         1
# Choice's by Au Bon Pain                        *     HE_Fail    Eating & Drinking w/ Take Out       4
#                                                ***   HE_Fail    Eating & Drinking w/ Take Out       1
# City Sports                                    *     HE_Fail    Retail Food                         2
# Convenient Corner                              *     HE_Filed   Retail Food                         1
# DUNKIN DONUTS(FRANKLIN)                        none  HE_Pass    Eating & Drinking w/ Take Out       1
# Foumami                                        none  HE_Pass    Eating & Drinking w/ Take Out       1
# Great Chef                                     *     HE_Pass    Eating & Drinking w/ Take Out       9
# Harvard Stadium Stand No. 2                    none  HE_Pass    Eating & Drinking w/ Take Out       1
# KANTIN                                         *     HE_Fail    Eating & Drinking w/ Take Out       3
#                                                ***   HE_Fail    Eating & Drinking w/ Take Out       1
# LOLLICUP TEA ZONE                              *     HE_Fail    Eating & Drinking w/ Take Out       1
#                                                ***   HE_Fail    Eating & Drinking w/ Take Out       1
# Max Brenner                                    *     HE_Fail    Eating & Drinking                  11
#                                                **    HE_Fail    Eating & Drinking                   1
#                                                ***   HE_Fail    Eating & Drinking                   3
# Mcdonalds (Warren St.)                         *     HE_Fail    Eating & Drinking w/ Take Out       2
#                                                ***   HE_Fail    Eating & Drinking w/ Take Out       1
# Mud House                                      *     HE_Pass    Eating & Drinking                   2
#                                                ***   HE_Pass    Eating & Drinking                   1
# Nevilles Bakery & Restaurant                   *     HE_FailExt Eating & Drinking w/ Take Out       8
#                                                **    HE_FailExt Eating & Drinking w/ Take Out       1
# Panera Bread Bakery Cafe                       *     HE_Pass    Eating & Drinking                   5
#                                                ***   HE_Pass    Eating & Drinking                   1
# Pho Viets                                      *     HE_Filed   Eating & Drinking w/ Take Out       1
# Pollos A La Brasa Beto's                       *     HE_Filed   Eating & Drinking w/ Take Out       7
# Popeyes Chicken & Biscuit                      *     HE_Fail    Eating & Drinking w/ Take Out       2
# SOUTH BOSTON CHINESE                           *     HE_Pass    Eating & Drinking w/ Take Out       4
#                                                **    HE_Pass    Eating & Drinking w/ Take Out       1
#                                                ***   HE_Pass    Eating & Drinking w/ Take Out       1
# Samurai Kuang Eatery                           *     HE_Pass    Eating & Drinking w/ Take Out       4
#                                                ***   HE_Pass    Eating & Drinking w/ Take Out       1
# Savory Food Truck No.  3 (P-33-235)            *     HE_Filed   Mobile Food Walk On                 1
# Shanghai Social Club                           *     HE_Pass    Eating & Drinking                   2
#                                                **    HE_Pass    Eating & Drinking                   1
#                                                ***   HE_Pass    Eating & Drinking                   1
# Shaw's Supermarket No. 586                     *     HE_Fail    Retail Food                         6
#                                                ***   HE_Fail    Retail Food                         1
# Squeeze Cafe & Juice Bar                       *     HE_Filed   Eating & Drinking w/ Take Out       1
# THE CATERED AFFAIR @ BOS. PUBLIC LIBRARY(T.O.) *     HE_Fail    Eating & Drinking w/ Take Out       2
# THE CATERED AFFAIR @ BOSTON PUBLIC LIBRARY     *     HE_Fail    Eating & Drinking                   3
# WORLD TRADE CENTER                             *     HE_Fail    Eating & Drinking w/ Take Out       4

# %% [markdown]
# There seem to be some mistakes in Yelp's condensed records. To see why, note that in the city records above, the inspection of Samurai Kuang Eatery on August 12 is marked as passing. For that inspection, four 1-star and one 3-star violations are noted, but this is only because that inspection was a follow-up to an inspection from one week before, which found those violations. This can be seen in the excerpt of city data below. Unfortunately, the Yelp data treats each of these inspections identically, marking four 1-star and one 3-star violations for each inspection, which is quite misleading. This mistaken double-entry of health violations happens frequently throughout the Yelp dataset.
#
# We will see later that this issue, once we make an appropriate correction for it, will not at all impede the central purpose of this project.

# %%
inspections[
    (inspections.name.str.startswith('Samurai Kuang')) & 
    (inspections.result_date.astype(str) >= '2014-08') &
    (inspections.result_date.astype(str) < '2015') 
][[
        'name', 'result', 'result_date', 'level', 'description', 'comments'
    ]].sort_values('result_date')
# Out:
#                        name   result result_date level  \
# 63245  Samurai Kuang Eatery  HE_Fail  2014-08-05     *
# 63322  Samurai Kuang Eatery  HE_Fail  2014-08-05   ***
# 63343  Samurai Kuang Eatery  HE_Fail  2014-08-05     *
# 63378  Samurai Kuang Eatery  HE_Fail  2014-08-05     *
# 63480  Samurai Kuang Eatery  HE_Fail  2014-08-05     *
# 63080  Samurai Kuang Eatery  HE_Pass  2014-08-12     *
# 63148  Samurai Kuang Eatery  HE_Pass  2014-08-12     *
# 63204  Samurai Kuang Eatery  HE_Pass  2014-08-12     *
# 63352  Samurai Kuang Eatery  HE_Pass  2014-08-12     *
# 63410  Samurai Kuang Eatery  HE_Pass  2014-08-12   ***
# 63212  Samurai Kuang Eatery  HE_Fail  2014-12-02   ***
# 63382  Samurai Kuang Eatery  HE_Fail  2014-12-02   ***
# 63186  Samurai Kuang Eatery  HE_Pass  2014-12-03   ***
# 63448  Samurai Kuang Eatery  HE_Pass  2014-12-03   ***
#
#                                   description  \
# 63245               Non-Food Contact Surfaces
# 63322                            Cold Holding
# 63343  Improper Maintenance of Walls/Ceilings
# 63378          Improper Maintenance of Floors
# 63480                  Equipment Thermometers
# 63080  Improper Maintenance of Walls/Ceilings
# 63148               Non-Food Contact Surfaces
# 63204          Improper Maintenance of Floors
# 63352                  Equipment Thermometers
# 63410                            Cold Holding
# 63212                      Hot and Cold Water
# 63382                            Cold Holding
# 63186                      Hot and Cold Water
# 63448                            Cold Holding
#
#                                                 comments
# 63245  Back door opened  without screen / Provide scr...
# 63322  Sushi grade salmon 51F  White fish 50F / Provi...
# 63343  Hood vents with visible grease build up / Clea...
# 63378  Floors under cookline  around handsink heavily...
# 63480             Dish machine gauge is broken / Repair.
# 63080  Hood vents with visible grease build up / Clea...
# 63148  Back door opened  without screen / Provide scr...
# 63204  Floors under cookline  around handsink heavily...
# 63352             Dish machine gauge is broken / Repair.
# 63410  Sushi grade salmon 51F  White fish 50F / Provi...
# 63212  Establishment does not have hot running water ...
# 63382  Fried shrimp 75F  Raw shell eggs 50F / Provide...
# 63186  Establishment does not have hot running water ...
# 63448  Fried shrimp 75F  Raw shell eggs 50F / Provide...

# %%
violations[
    (violations.name.str.startswith('Samurai Kuang')) & 
    (violations.date.astype(str) >= '2014-08') &
    (violations.date.astype(str) < '2015') 
].drop(['reviews','rating','latitude','longitude'], 1).sort_values('date')
# Out:
#             date restaurant_id  *  **  ***                  name
# 25897 2014-08-05      B1oX4boV  4   0    1  Samurai Kuang Eatery
# 25898 2014-08-12      B1oX4boV  4   0    1  Samurai Kuang Eatery
# 25899 2014-12-02      B1oX4boV  0   0    2  Samurai Kuang Eatery
# 25900 2014-12-03      B1oX4boV  0   0    2  Samurai Kuang Eatery

# %% [markdown]
# In light of the excerpts and discussion above, we can now consider the advantages of each dataset of inspection results.
#
# The City of Boston's dataset is kept continually up-to-date, with new results being entered as they occur, while Yelp's data ends in mid 2015. Boston's dataset is also more complete in the sense that each violation is categorized in much finer detail than a simple a three-level severity measurement. This information could possibly be used in a predictive model &mdash; for example, perhaps some specific types of violations are more prone to repeat than others are.
#
# Yelp's dataset was developed with the express support of the City of Boston, working toward a purpose very similar to the purpose of the present project. This dataset provides latitude/longitude coordinates for every inspection location listed. Also, Yelp's inspection records are designed for easy matching to another extensive dataset (not yet shown here) containing the text of Yelp reviews for each establishment.
#
# Given enough time and resources, the limitations of either dataset could be corrected. However, I believe that for our present purpose, the advantages of Yelp's inspection dataset far outweigh its limitations.

# %% [markdown]
# ### Service Request Calls
#
# Boston residents are able to dial "311" and report public property issues such as rodent sightings, unsanitary conditions, streetlight outages, and so forth. Records of these 311 service requests, from July 2011 to present, are available from [data.cityofboston.gov](https://data.cityofboston.gov/City-Services/311-Service-Requests/awu8-dc52).
#
# Each call record includes the following relevant information:
# * The date the complaint was made
# * The date the issue was resolved
# * Various descriptions of the nature of the complaint
# * Latitude/longitude coordinates of the issue
#
# Below, we load the data and display some randomly-selected lines from it.

# %%
services = pd.read_csv(
    'data/311__Service_Requests.csv', 
    usecols = [
       'OPEN_DT', 'CLOSED_DT', 'CASE_STATUS', 'CLOSURE_REASON', 'CASE_TITLE', 'SUBJECT', 'REASON',
       'TYPE', 'LATITUDE', 'LONGITUDE'
    ],
    parse_dates=['OPEN_DT', 'CLOSED_DT'], 
    infer_datetime_format = True
)
services.columns = [
    'open',         # date the complaint was registered
    'closed',       # date the complaint was resolved
    'status',       # open or closed
    'closure',      # details of how the complaint was closed (NaN if open)
    'title',        # description of the issue
    'subject',      # category of the issue (e.g. public works, civil rights, animal control, etc.)
    'reason',       # more specific category (often very similar to the "title")
    'type',         # usually identical to the "title" 
    'latitude',      
    'longitude'      
]
services = services.sort_values(['open', 'reason'])
services.sample(8)
# Out:
#                       open              closed  status  \
# 316304 2011-09-29 07:37:52 2011-09-29 15:07:59  Closed
# 669093 2013-08-19 15:02:08 2013-08-19 15:12:11  Closed
# 525745 2013-09-23 14:57:19 2013-09-26 21:48:15  Closed
# 75745  2015-08-05 13:47:08 2015-08-10 16:37:44  Closed
# 201423 2015-11-14 14:06:18 2015-11-15 08:03:01  Closed
# 115340 2011-08-30 07:58:05 2011-08-30 08:10:22  Closed
# 584670 2015-09-16 21:59:00                 NaT    Open
# 453203 2014-07-30 11:08:14 2014-08-04 16:37:46  Closed
#
#                                                   closure  \
# 316304  Case Closed Case Resolved pothole patched on 0...
# 669093  Case Closed Case Resolved  The tree was pruned...
# 525745                   Case Closed Bulk Item Automation
# 75745   Case Closed. Closed date : 2015-08-10 16:37:44...
# 201423  Case Closed. Closed date : 2015-11-15 08:03:01...
# 115340  Case Closed Case Scheduled Items have been sch...
# 584670                                                NaN
# 453203                   Case Closed Bulk Item Automation
#
#                               title                        subject  \
# 316304          Highway Maintenance        Public Works Department
# 669093    Tree Maintenance Requests  Parks & Recreation Department
# 525745  Schedule a Bulk Item Pickup        Public Works Department
# 75745     Schedule Bulk Item Pickup        Public Works Department
# 201423          Pick up Dead Animal        Public Works Department
# 115340  Schedule a Bulk Item Pickup        Public Works Department
# 584670    Tree Maintenance Requests  Parks & Recreation Department
# 453203  Schedule a Bulk Item Pickup        Public Works Department
#
#                      reason                            type  latitude  \
# 316304  Highway Maintenance             Highway Maintenance   42.3131
# 669093                Trees       Tree Maintenance Requests   42.3088
# 525745           Sanitation     Schedule a Bulk Item Pickup   42.3014
# 75745            Sanitation  Schedule a Bulk Item Pickup SS   42.3495
# 201423      Street Cleaning             Pick up Dead Animal   42.3499
# 115340           Sanitation     Schedule a Bulk Item Pickup   42.3597
# 584670                Trees       Tree Maintenance Requests   42.2838
# 453203           Sanitation     Schedule a Bulk Item Pickup   42.3004
#
#         longitude
# 316304   -71.1238
# 669093   -71.1046
# 525745   -71.0568
# 75745    -71.0893
# 201423   -71.0897
# 115340   -71.0693
# 584670   -71.1206
# 453203   -71.0807

# %% [markdown]
# Each complaint is described, often redundantly, by a "title," a "subject," a "reason," and a "type." In the dataset, there are 7837 different titles, 18 different subjects, 61 different reasons, and 215 different types. We will use "reasons" as a natural way to categorize complaints, because they strike a balance between being overly specific (as in the thousands of different "titles") and not being descriptive enough (like the handful of vague "subjects").
#
# For future use and convenience, we will store the names of the most commonly used "reasons." These are shown below.

# %%
reason = services.reason.value_counts().head(45).reset_index()['index']
reason
# Out:
# 0                            Sanitation
# 1                   Highway Maintenance
# 2                       Street Cleaning
# 3                         Street Lights
# 4                       Signs & Signals
# 5                               Housing
# 6                             Recycling
# 7      Enforcement & Abandoned Vehicles
# 8                              Building
# 9                                 Trees
# 10                             Graffiti
# 11          Employee & General Comments
# 12               Environmental Services
# 13            Park Maintenance & Safety
# 14                     Code Enforcement
# 15    Administrative & General Requests
# 16                        Animal Issues
# 17                         Notification
# 18                               Health
# 19                         Call Inquiry
# 20                           Operations
# 21     Traffic Management & Engineering
# 22                               Survey
# 23                           Disability
# 24                           Catchbasin
# 25                    Abandoned Bicycle
# 26                       Needle Program
# 27                             Programs
# 28             Sidewalk Cover / Manhole
# 29                         Fire Hydrant
# 30                      Fire Department
# 31                      General Request
# 32                                 MBTA
# 33                 Weights and Measures
# 34       Investigations and Enforcement
# 35                    Noise Disturbance
# 36                         Water Issues
# 37                         Alert Boston
# 38         Volunteer & Corporate Groups
# 39            Generic Noise Disturbance
# 40                              Pothole
# 41                         Boston Bikes
# 42                   Parking Complaints
# 43                             Cemetery
# 44          Office of The Parking Clerk
# Name: index, dtype: object

# %% [markdown]
# ## Extracting Features from the Data
#
# To develop a model for predicting a food service establishment's likely outcome (pass or fail) from an unannounced health inspection, we will make use of two main types of information:
# * Conditions in the area near the business in the recent past, as drawn from the service call request data outlined above.
# * Customer impressions of the business, as given in Yelp ratings and written reviews.
#
# The Yelp dataset of inspection results already has some basic features drawn from customer impressions. These are the number of reviews, and the average customer rating for each establishment. These features are flawed in a few ways, perhaps most importantly in that they are summarized over all time (rather than just up to the date of inspection), so we will eventually replace them with better features drawn from the deeper Yelp review data available.
#
# In the code below, we extract potential features related to conditions in the area near each inspected business in the recent past. For each of the common service call "reasons" discussed before, we count the number of times that particular issue has been reported near the inspected business, between 5 and 15 days before the inspection. Nearness is judged here in terms of distance in latitude/longitude coordinates; roughly speaking, we are counting any reports that have occurred within about 3 miles of the inspected business. *(The time window and distance used here were chosen after some light experimentation, but can be further adjusted for better predictive ability.)*
#
# For each business inspected, we also measure the length of time that has passed since the previous inspection.

# %%
pd.options.mode.chained_assignment = None
for j in range(45):
    violations[reason[j]] = nan

violations['delay'] = nan
    
for row in range(len(violations)):
    c = (violations.latitude.iloc[row], violations.longitude.iloc[row])
    ri = violations.restaurant_id.iloc[row]
    t = violations.date.iloc[row]
    tlast = violations[(violations.date <= t - timedelta(days = 1)) & (violations.restaurant_id == ri)].date.max()
    violations['delay'].iloc[row] = t - tlast
    s = services[
            (services.open < t - timedelta(days = 5)) &
            (services.open > t - timedelta(days = 15)) &
            ((services.latitude - c[0])**2 + (services.longitude - c[1])**2 < .0025)
    ]
    for j in range(45):
        violations.iloc[row,j+10] = sum(s.reason == reason[j])
        
violations['delay'] = (violations.delay) / (timedelta(days=1))
violations['delay'] = violations.delay.astype(float)

# %% [markdown]
# Below, for demonstration purposes, we display the information for inspections that occurred on July 22, 2014. With these we can illustrate the meaning of the features extracted above. For example, an inspection occurred at Penguin Pizza that day. This inspection was failed, since violations were found. Between 5 and 15 days prior to this inspection, there were 499 complaints related to "sanitation" in the area around Pengin Pizza, 325 complaints related to "highway maintenance," 104 related  to "street cleaning," and so on. It had been 208 days since Penguin Pizza's last inspection.
#
# Farther down in the table below, we see that Rebecca's Cafe was inspected the same day, and passed (no violations). 5 to 15 days prior to this inspection, there were 452 complaints related to "sanitation" in the area around Rebecca's Cafe, 297 complaints related to "highway maintenance," and so forth.
#
# Observe that the "delay" column, which marks the number of days that have passed since each establishment was last inspected, contains numbers of two very distinct magnitudes. This reflects the fact that many inspections are follow-ups to recent failed inspections. As shown before, the violations information given for these follow-ups is often not accurate.

# %%
violations[violations.date == '2014-07-22'].drop(['restaurant_id','latitude','longitude'], 1)
# Out:
#             date   *  **  ***                    name  reviews  rating  \
# 9951  2014-07-22  22   2   12     New Saigon Sandwich      257     4.0
# 1014  2014-07-22   8   0    1           Penguin Pizza      386     4.0
# 20419 2014-07-22   3   0    0               Starbucks       17     4.0
# 802   2014-07-22  13   0    0      My Thai Vegan Cafe      421     4.0
# 27566 2014-07-22   9   2    1     Al Dente Restaurant      529     4.0
# 12117 2014-07-22   5   0    0     Restaurante Cesaria       30     4.0
# 12574 2014-07-22   6   2    2                Anh Hong      113     4.0
# 11026 2014-07-22  10   2    2          Teriyaki House      189     3.5
# 11783 2014-07-22  35   2   11               Xinh Xinh      608     4.0
# 33509 2014-07-22   7   2    2             Benevento's      194     3.5
# 3114  2014-07-22   0   0    0          Rebecca's Cafe        3     1.5
# 30848 2014-07-22   4   0    0  Chipotle Mexican Grill       94     3.5
# 34986 2014-07-22   4   0    0     Savin Bar & Kitchen      162     3.5
# 31300 2014-07-22   2   1    0                  Boloco       74     3.5
#
#        Sanitation  Highway Maintenance  Street Cleaning  ...    Water Issues  \
# 9951        523.0                305.0            125.0  ...             1.0
# 1014        499.0                325.0            104.0  ...             0.0
# 20419       565.0                359.0            135.0  ...             1.0
# 802         522.0                306.0            124.0  ...             1.0
# 27566       381.0                287.0             90.0  ...             1.0
# 12117       662.0                339.0            196.0  ...             0.0
# 12574       549.0                220.0            186.0  ...             0.0
# 11026       555.0                315.0            152.0  ...             1.0
# 11783       522.0                306.0            124.0  ...             1.0
# 33509       380.0                287.0             90.0  ...             1.0
# 3114        452.0                297.0            104.0  ...             1.0
# 30848       521.0                367.0            104.0  ...             1.0
# 34986       608.0                281.0            198.0  ...             1.0
# 31300       444.0                297.0            105.0  ...             1.0
#
#        Alert Boston  Volunteer & Corporate Groups  Generic Noise Disturbance  \
# 9951            0.0                           0.0                        0.0
# 1014            0.0                           0.0                        0.0
# 20419           0.0                           0.0                        0.0
# 802             0.0                           0.0                        0.0
# 27566           0.0                           0.0                        0.0
# 12117           0.0                           0.0                        1.0
# 12574           0.0                           0.0                        1.0
# 11026           0.0                           0.0                        0.0
# 11783           0.0                           0.0                        0.0
# 33509           0.0                           0.0                        0.0
# 3114            0.0                           0.0                        0.0
# 30848           0.0                           0.0                        0.0
# 34986           0.0                           0.0                        1.0
# 31300           0.0                           0.0                        0.0
#
#        Pothole  Boston Bikes  Parking Complaints  Cemetery  \
# 9951       0.0           0.0                 0.0       2.0
# 1014       0.0           0.0                 0.0       0.0
# 20419      0.0           0.0                 0.0       2.0
# 802        0.0           0.0                 0.0       2.0
# 27566      0.0           0.0                 0.0       2.0
# 12117      0.0           0.0                 0.0       0.0
# 12574      0.0           0.0                 0.0       0.0
# 11026      0.0           0.0                 0.0       2.0
# 11783      0.0           0.0                 0.0       2.0
# 33509      0.0           0.0                 0.0       2.0
# 3114       0.0           0.0                 0.0       2.0
# 30848      0.0           0.0                 0.0       2.0
# 34986      0.0           0.0                 0.0       2.0
# 31300      0.0           0.0                 0.0       2.0
#
#        Office of The Parking Clerk  delay
# 9951                           0.0  186.0
# 1014                           0.0  208.0
# 20419                          0.0  148.0
# 802                            0.0  204.0
# 27566                          0.0  140.0
# 12117                          0.0    7.0
# 12574                          0.0  166.0
# 11026                          0.0   11.0
# 11783                          0.0    1.0
# 33509                          0.0  140.0
# 3114                           0.0  194.0
# 30848                          0.0  273.0
# 34986                          0.0    7.0
# 31300                          0.0  141.0
#
# [14 rows x 53 columns]

# %% [markdown]
# To get an early sense of the relationship between the features extracted above and the prevalence of inspection failures, we may examine the correlation coefficients between each feature and each of the three severity levels, as follows.

# %%
violations[['*','**','***'] + list(reason[0:45]) + ['reviews', 'rating', 'delay']].corr().iloc[0:3,3:]
# Out:
#      Sanitation  Highway Maintenance  Street Cleaning  Street Lights  \
# *      0.108451             0.154236        -0.010561      -0.009663
# **     0.075268             0.075548        -0.010698      -0.000860
# ***    0.047084             0.073965        -0.021544      -0.038988
#
#      Signs & Signals   Housing  Recycling  Enforcement & Abandoned Vehicles  \
# *           0.089541  0.074555   0.131223                          0.105753
# **          0.054662  0.049962   0.080476                          0.058439
# ***         0.046897  0.039782   0.063104                          0.046075
#
#      Building     Trees    ...     Volunteer & Corporate Groups  \
# *    0.112984  0.105726    ...                         0.097123
# **   0.062179  0.074257    ...                         0.069487
# ***  0.062928  0.059040    ...                         0.050193
#
#      Generic Noise Disturbance   Pothole  Boston Bikes  Parking Complaints  \
# *                     0.033182  0.107008      0.018981            0.020321
# **                   -0.004128  0.041324      0.003882            0.018903
# ***                   0.017577  0.072613      0.012584            0.002113
#
#      Cemetery  Office of The Parking Clerk   reviews    rating     delay
# *    0.052117                     0.053696  0.073952 -0.015761 -0.157320
# **   0.049752                     0.024959  0.049787 -0.029659 -0.115727
# ***  0.023598                     0.018101  0.024487 -0.013495 -0.122651
#
# [3 rows x 48 columns]

# %% [markdown]
# For some features, the correlation with violations is essentially nonexistent, but for others there is a weak correlation. Many of these correlations are statistically significant. For example, here are the *p*-values from tests of correlation for each of the first 10 features above.

# %%
pd.DataFrame({
        'reason':[reason[k] for k in range(0,10)], 
        'p-value (*)':[stats.pearsonr(violations['*'], violations[reason[k]])[1] for k in range(0,10)],
        'p-value (**)':[stats.pearsonr(violations['**'], violations[reason[k]])[1] for k in range(0,10)],
        'p-value (***)':[stats.pearsonr(violations['***'], violations[reason[k]])[1] for k in range(0,10)]
    },index=range(0,10)).set_index('reason')
# Out:
#                                    p-value (*)  p-value (**)  p-value (***)
# reason
# Sanitation                        4.375221e-47  1.742967e-23   4.325481e-10
# Highway Maintenance               6.478502e-94  1.196805e-23   9.862901e-23
# Street Cleaning                   1.617405e-01  1.563345e-01   4.306347e-03
# Street Lights                     2.004226e-01  9.092561e-01   2.370376e-07
# Signs & Signals                   1.375353e-32  4.237129e-13   5.070446e-10
# Housing                           4.517745e-23  3.500459e-11   1.342927e-07
# Recycling                         2.801139e-68  1.264433e-26   5.799759e-17
# Enforcement & Abandoned Vehicles  7.591063e-45  9.236586e-15   1.009582e-09
# Building                          5.615606e-51  1.633028e-16   7.070723e-17
# Trees                             7.989013e-45  6.710996e-23   4.910811e-15

# %% [markdown]
# Returning to the table of correlation coefficients above, on the far right side of the table we see that the average customer rating for establishments is somewhat negatively correlated with the number of violations found, which is not surprising. However, we alse see a stronger negative correlation between the "delay" (the length of time that has passed since the last inspection) and the number of violations found. This indicates that the more time has passed since the last inspection, the fewer violations are found &mdash; or in other words, establishments are most likely to be in violation of health codes shortly after their last inspection. This seems nonsensical; indeed, it is merely an artifact of the "mistaken double-entry of health violations" that was pointed out before.
#
# Fortunately, the goal of this project gives us ample justification for ignoring any data from follow-up inspections. We seek a model for identifying businesses that are likely to fail an **unannounced** health inspection. Any business that has already failed a recent inspection will necessarily be inspected again, regardless of any prediction we might make about the outcome of that follow-up. So in the context of this project, there is no value to the City of Boston in predicting the outcomes of follow-up inspections. Therefore in the remaining analysis, we will exclude any data from follow-up inspections, focusing solely on the outcomes of inspections that were not expected in advance.
#
# Below, we calculate the correlation coefficients between each feature and each of the three severity levels, but now omitting follow-up inspections. In most cases where there was correlation before, it is now stronger.

# %%
violations[violations.delay > 45][['*','**','***'] + list(reason[0:45]) + ['reviews', 'rating', 'delay']].corr().iloc[0:3,3:]
# Out:
#      Sanitation  Highway Maintenance  Street Cleaning  Street Lights  \
# *      0.139246             0.195804        -0.007455      -0.003573
# **     0.092148             0.110467         0.004545      -0.007807
# ***    0.083102             0.125820        -0.020036      -0.029770
#
#      Signs & Signals   Housing  Recycling  Enforcement & Abandoned Vehicles  \
# *           0.119235  0.099797   0.157217                          0.135949
# **          0.084856  0.067311   0.098524                          0.076487
# ***         0.081129  0.066252   0.087781                          0.081670
#
#      Building     Trees    ...     Volunteer & Corporate Groups  \
# *    0.157053  0.177941    ...                         0.105806
# **   0.093464  0.112405    ...                         0.078871
# ***  0.100093  0.117873    ...                         0.062146
#
#      Generic Noise Disturbance   Pothole  Boston Bikes  Parking Complaints  \
# *                     0.033354  0.117984      0.036522            0.042902
# **                    0.001561  0.058061      0.018840            0.025826
# ***                   0.012172  0.091903      0.023659            0.019698
#
#      Cemetery  Office of The Parking Clerk   reviews    rating     delay
# *    0.083069                     0.059529  0.066402 -0.020065  0.016038
# **   0.066199                     0.027245  0.044643 -0.040314  0.012783
# ***  0.042357                     0.023871  0.030237 -0.019569  0.014625
#
# [3 rows x 48 columns]

# %% [markdown]
# ## Some Hypothesis Tests
#
# Since the question we wish to answer &mdash; will a given establishment fail an unannounced health inspection or not? &mdash; is binary in nature, let's test the influence that our environmental features have on the proportion of failed inspections. For each kind of common issue that may be reported through service calls, we can test the following hypotheses.
#
# **Null hypothesis:** Establishments where the issue has been reported recently and nearby fail health inspections at the *same* rate as establishments where the issue has not been reported recently and nearby.
#
# **Alternative hypothesis:** Establishments where the issue has been reported recently and nearby fail health inspections at a *different* rate than establishments where the issue has not been reported recently and nearby.
#
# Building upon [Allen Downey's ``HypothesisTest`` class](https://github.com/AllenDowney/CompStats/blob/master/hypothesis.ipynb), the following code provides a method to test for a difference in proportions.

# %%
class HypothesisTest(object):
    """Represents a hypothesis test."""

    def __init__(self, data):
        """Initializes.

        data: data in whatever form is relevant
        """
        self.data = data
        self.MakeModel()
        self.actual = self.TestStatistic(data)
        self.test_stats = None

    def PValue(self, iters=1000):
        """Computes the distribution of the test statistic and p-value.

        iters: number of iterations

        returns: float p-value
        """
        self.test_stats = np.array([self.TestStatistic(self.RunModel()) 
                                       for _ in range(iters)])

        count = sum(self.test_stats >= self.actual)
        return count / iters

    def MaxTestStat(self):
        """Returns the largest test statistic seen during simulations.
        """
        return max(self.test_stats)

    def PlotHist(self, label=None):
        """Draws a Cdf with vertical lines at the observed test stat.
        """
        ys, xs, patches = pyplot.hist(ht.test_stats, color=COLOR4)
        pyplot.vlines(self.actual, 0, max(ys), linewidth=3, color='0.8')
        pyplot.xlabel('test statistic')
        pyplot.ylabel('count')

    def TestStatistic(self, data):
        """Computes the test statistic.

        data: data in whatever form is relevant        
        """
        raise UnimplementedMethodException()

    def MakeModel(self):
        """Build a model of the null hypothesis.
        """
        pass

    def RunModel(self):
        """Run the model of the null hypothesis.

        returns: simulated data
        """
        raise UnimplementedMethodException()


class DiffPropsPermute(HypothesisTest):
    """Tests a difference in proportions by permutation."""

    def TestStatistic(self, data):
        """Computes the test statistic.

        data: data in whatever form is relevant        
        """
        group1, group2 = data
        test_stat = abs(sum(group1)/len(group1) - sum(group2)/len(group2))
        return test_stat

    def MakeModel(self):
        """Build a model of the null hypothesis.
        """
        group1, group2 = self.data
        self.n, self.m = len(group1), len(group2)
        self.pool = np.hstack((group1, group2))

    def RunModel(self):
        """Run the model of the null hypothesis.

        returns: simulated data
        """
        np.random.shuffle(self.pool)
        data = self.pool[:self.n], self.pool[self.n:]
        return data

# %% [markdown]
# For example, we can test whether businesses that are near the sites of recent complaints related to "environmental services" are more likely than other businesses to fail a health inspection. (Note that "environmental services" complaints largely consist of rodent sightings.)
#
# We perform the test below.

# %%
set1 = violations[(violations.delay > 45) & (violations['Environmental Services'] == 0)][['*','**','***']] 
set2 = violations[(violations.delay > 45) & (violations['Environmental Services'] > 0)][['*','**','***']]
data1 = (set1['*'] + set1['**'] + set1['***'] > 0)
data2 = (set2['*'] + set2['**'] + set2['***'] > 0)
ht_data = (data1, data2)
ht = DiffPropsPermute(ht_data)
(ht.TestStatistic(ht_data), ht.PValue(iters=1000))
# Out:
# (0.036418197095186677, 0.78100000000000003)

# %% [markdown]
# There is no evidence to indicate a difference in failure rates between businesses with *zero* nearby environmental services complaints and businesses with *more than zero* such complaints. However, businesses with exactly *zero* of these complaints nearby are quite rare; the vast majority of inspected businesses are near at least 10 of them.
#
# Is there a difference between businesses that are near very few (less than 10) recent environmental services complaints and others? Here is the test:

# %%
set1 = violations[(violations.delay > 45) & (violations['Environmental Services'] < 10)][['*','**','***']]
set2 = violations[(violations.delay > 45) & (violations['Environmental Services'] >= 10)][['*','**','***']]
data1 = (set1['*'] + set1['**'] + set1['***'] > 0)
data2 = (set2['*'] + set2['**'] + set2['***'] > 0)
ht_data = (data1, data2)
ht = DiffPropsPermute(ht_data)
(ht.TestStatistic(ht_data), ht.PValue(iters=1000))
# Out:
# (0.21239383082277097, 0.0)

# %% [markdown]
# The *p*-value here is indistinguishable from zero. There is a statistically significant difference in the inspection failure rates of businesses that are near at least 10 recent environmental services complaints. In our data, these establishments fail inspections at a rate 21% higher than others.
#
# As another example, there is a significant difference in failure rates between businesses that are near very few (less than 100) recent "sanitation" complaints and other businesses:

# %%
set1 = violations[(violations.delay > 45) & (violations['Sanitation'] < 100)][['*','**','***']]
set2 = violations[(violations.delay > 45) & (violations['Sanitation'] >= 100)][['*','**','***']]
data1 = (set1['*'] + set1['**'] + set1['***'] > 0)
data2 = (set2['*'] + set2['**'] + set2['***'] > 0)
ht_data = (data1, data2)
ht = DiffPropsPermute(ht_data)
(ht.TestStatistic(ht_data), ht.PValue(iters=1000))
# Out:
# (0.25831625477195092, 0.0)

# %% [markdown]
# Similar results can be found for many of the other environmental features, which suggests that these features &mdash; after some refinement &mdash; could be useful in developing a model to fulfill our stated purpose.
#
# As for features derived from customer experiences, we have further work to do. At the present time we may ask, is there a difference in failure rates between businesses with a high average customer rating and others? It is not clear what we should use as a cutoff value between "high" ratings and others, so let's see the results for every possible rating cutoff:

# %%
for c in np.arange(1.5, 5, .5):
    set1 = violations[(violations.delay > 45) & (violations.rating <= c)][['*','**','***']]
    set2 = violations[(violations.delay > 45) & (violations.rating > c)][['*','**','***']]
    data1 = (set1['*'] + set1['**'] + set1['***'] > 0)
    data2 = (set2['*'] + set2['**'] + set2['***'] > 0)
    ht_data = (data1, data2)
    ht = DiffPropsPermute(ht_data)
    print(
        'With cutoff ' + str(c) + 
        ', the p-value is ' + str(ht.PValue(iters=1000)) + 
        ' and the actual difference in proportions is ' + str(ht.TestStatistic(ht_data))
    )
# Out:
# With cutoff 1.5, the p-value is 0.7 and the actual difference in proportions is 0.0271862170973
# With cutoff 2.0, the p-value is 0.735 and the actual difference in proportions is 0.00988379783767
# With cutoff 2.5, the p-value is 0.266 and the actual difference in proportions is 0.0173930022535
# With cutoff 3.0, the p-value is 0.782 and the actual difference in proportions is 0.00309852093128
# With cutoff 3.5, the p-value is 0.036 and the actual difference in proportions is 0.0230290541312
# With cutoff 4.0, the p-value is 0.0 and the actual difference in proportions is 0.116197340704
# With cutoff 4.5, the p-value is 0.513 and the actual difference in proportions is 0.136516314779

# %% [markdown]
# As noted before, the average customer rating feature is deeply flawed, but even if we put that fact aside for a moment, the prospects of using it to help distinguish between likely passes and likely failures is not promising. We only find statistically significant results when using a rating cutoff of 4.0, and then the actual difference in failure rates is only about 12%.
#
# We will have more success after extracting some much more detailed features from the text of Yelp reviews, as mentioned previously.

# %% [markdown]
# ## Some preliminary work with Yelp reviews text
#
# Loading the dataset of Yelp reviews text, and aligning it for reference with the violations dataset:

# %%
import json
from pandas.io.json import json_normalize

reviews = pd.DataFrame()
with open('data/yelp_academic_dataset_review.json', 'r') as f:
    for line in f:
        df = pd.read_json(line).set_index('review_id').iloc[[0]].drop(['user_id','votes','type'], axis=1)
        reviews = reviews.append(df)
reviews = reviews.rename(
    columns = {'business_id':'yelp_id'}
).merge(
    idtable, 
    on = 'yelp_id'
).drop(
    'yelp_id', 
    axis = 1
)
reviews[['date']] = pd.to_datetime(reviews.date)

# %%
reviews
# Out:
#                      review_id       date  stars  \
# 0       OeT5kgUOe3vcN7H6ImVmZQ 2005-08-26      3
# 1       qq3zF2dDUh3EjMDuKBqhEA 2005-11-23      3
# 2       i3eQTINJXe3WUmyIpvhE9w 2005-11-23      3
# 3       cnAvoSxsMtyuPEmB9wJ0Nw 2006-02-24      5
# 4       bs4VNLZUHi0Rh7Lz1BRKyw 2007-09-06      3
# 5       F1v9N06fzLCU9M2R3NEGCw 2007-11-11      4
# 6       zQH071b6x9g1ZHbhJnaNKw 2005-12-11      4
# 7       NR33cz48RMMYfT79MaDxKQ 2006-04-19      4
# 8       70bfgIrBIZYu3HmgAGtAEQ 2008-05-06      4
# 9       AUmMDjcDYfCTLmNbRv2dQA 2008-08-02      4
# 10      liHYhgmHEbceTyOYzKVl7g 2008-09-17      5
# 11      eR0CTPsBtOjjb6opzVg7Jg 2008-11-10      4
# 12      3cN4C7hy_GoMphDpQf00Ug 2008-11-14      5
# 13      1W-BMqk3LPBM42OLIS1v0g 2008-11-14      5
# 14      cQz86V2Gxelv51Ce8UH5lw 2008-12-11      4
# 15      Lgahkk0C2ce1wX6Jy63t5g 2009-01-09      5
# 16      4cn1rm9pB4ZXN2tGY1aC2A 2009-01-30      4
# 17      7QVCBraDmURf-Sl25xdJyw 2009-02-10      5
# 18      5iRFAyLUm8Q0v99RkNlBng 2009-05-12      3
# 19      WipxaK1Eol0CY_bkCkzuRQ 2009-07-11      5
# 20      4H8L2vvWVeujMW3eUoRbCg 2009-12-13      4
# 21      h0SXpANHq01ef8T903SRFg 2009-12-20      5
# 22      Ty9OFW4XKXEkMOODRtM3Nw 2010-02-26      5
# 23      A3G7juOA3FhsM98rmT_fcQ 2010-05-23      4
# 24      Vh6-UwG4p1ztlaQ-Slw2Lw 2010-06-16      5
# 25      y6_M2qQfjxYUsoWv37dAnA 2010-07-19      5
# 26      UeiPEguEG5a7y1K6QvP84A 2010-08-03      3
# 27      SeHtmrG0Fw8T0B3mnDqVBA 2010-09-14      4
# 28      btY2g2YiH5eIGzBUpPh1tw 2010-11-12      4
# 29      e2Iryt3MVuYGLmqRJTVQFA 2011-01-12      3
# ...                        ...        ...    ...
# 233617  WfyIeamtt7LinafKTUnpkg 2014-07-10      3
# 233618  KskSyTgqciO1aX6I357zgw 2014-07-18      4
# 233619  QD3ajafYsvR-tdH1Aa6RAg 2014-07-19      5
# 233620  cXBKHAJskpW0Qfn26Bf7Ow 2014-07-24      5
# 233621  2PXMl4hJR-tKiQ0I4HHT9g 2014-08-01      5
# 233622  dyEa9psIAylPCG6iHYdEJw 2014-08-18      5
# 233623  KTo7ehiSsz7Wi1AADM8HsQ 2014-09-06      5
# 233624  rIr_Dv4Y2MMcM44kapoEcA 2014-10-21      1
# 233625  ZZV0Li3I2HhJRn5JSdKd8w 2014-11-04      1
# 233626  4_K_pbH2ea53grUxz_9MWA 2014-12-03      1
# 233627  rFnwvRJzDl6mvrWBaaBvyA 2014-12-14      5
# 233628  KroK10DbHcSoldyVwS8BOg 2014-12-31      3
# 233629  FKhXlwh1EltHsg_PNADpjg 2015-01-15      2
# 233630  dGSjgvzatBbGzQikBPoOHg 2015-02-10      1
# 233631  nT0AtTykzlhbaB3qYCPBIA 2015-02-15      5
# 233632  XPHP3qwkUilF_W5PaOGkAw 2015-02-16      4
# 233633  6szCfIlowstJNBhCvgfEGg 2015-02-17      4
# 233634  gfGaM8XU3qkjscefNPXbmg 2015-02-27      5
# 233635  wdxiB7rLHtf2OV1MPFn_YA 2015-03-28      1
# 233636  JS-aBv1tr56T8P_6aHI6TA 2015-03-28      1
# 233637  gGVmkBxW75tPgWEk4QTO-A 2015-03-28      1
# 233638  E85Lax2uesnpFGd6bkgWtQ 2015-04-01      3
# 233639  uEklKXt41VVJuSvCXYkD9Q 2015-04-01      1
# 233640  K3gVGCN9Ut1BYv3Il7500w 2015-04-02      3
# 233641  YPFSPhbmUeKSXQuBcS_-Fw 2015-04-02      4
# 233642  mkh8utRKN-SxB0w3BZdaBg 2015-04-08      1
# 233643  IudBijF43YhIW43xEGN2Pg 2015-05-02      4
# 233644  yi2UniJKuf5WXPxThFko0A 2015-05-04      5
# 233645  ASzbI-6EULdMxW6KM-mr-w 2015-05-25      1
# 233646  xn4eknNK8LiPBi_rJeUTwA 2015-06-06      3
#
#                                                      text restaurant_id
# 0       This is a pretty typical cafe.  The sandwiches...      N6Ok7qOx
# 1       I agree with other reviewers - this is a prett...      N6Ok7qOx
# 2       Decent enough food, but very overpriced. Just ...      N6Ok7qOx
# 3       The muffins are great...esp the blueberry!  I ...      N6Ok7qOx
# 4       Well, well, well, look at me reviewing the res...      N6Ok7qOx
# 5       The only place downtown where you can get away...      N6Ok7qOx
# 6       This is the place I like to go for deli sandwi...      p03824Om
# 7       Delicato is a great place for lunch on the go ...      p03824Om
# 8       Delicato is a surprisingly tasty place for bei...      p03824Om
# 9       Did you ever notice that no matter where you g...      p03824Om
# 10      I think I ate here every day for a solid six m...      p03824Om
# 11      Whoa. This place is good. Monday through Frida...      p03824Om
# 12      This is easily one of my favorite places to ge...      p03824Om
# 13      Everyday I love this place more and more.  The...      p03824Om
# 14      This off the beaten path spot is a place you s...      p03824Om
# 15      Five stars for you!\r\n\r\nAs I sit here updat...      p03824Om
# 16      I always walked past this place on my way to V...      p03824Om
# 17      Delicato has become a regular in the lunch rot...      p03824Om
# 18      Just ate here for the first time and it's righ...      p03824Om
# 19      This is a great sandwich shop next to Old City...      p03824Om
# 20      Above average Deli.  Good Bread, good veggies,...      p03824Om
# 21      Consider this the "Cheers" of breakfast joints...      p03824Om
# 22      I love Delicato Cafe.  Whether it be the Frenc...      p03824Om
# 23      I eat here quite often because my office is on...      p03824Om
# 24      Delicato is by far my favorite lunch spot in t...      p03824Om
# 25      I had breakfast here, (couple of ham, egg and ...      p03824Om
# 26      Well, I have only had one experience here. I w...      p03824Om
# 27      Delicato is one of the premier cafe/lunch spot...      p03824Om
# 28      Two reasons I love Delicato? Breakfast and lun...      p03824Om
# 29      Super tasty & fast! We tried the COWGIRL MELT ...      p03824Om
# ...                                                   ...           ...
# 233617  A decent neighborhood joint with friendly serv...      qN3g1QOA
# 233618  Fast becoming a regular favorite. Food is grea...      qN3g1QOA
# 233619  Absolute go to place to order from. My boyfrie...      qN3g1QOA
# 233620  The best beef gyro I've ever had in my life. H...      qN3g1QOA
# 233621  Just stopped by for some Greek food! The chick...      qN3g1QOA
# 233622  I was babysitting at a house with no food near...      qN3g1QOA
# 233623  This place is amazing.\r\nDo yourself a favor ...      qN3g1QOA
# 233624  Attempting to get delivery from this place was...      qN3g1QOA
# 233625  First experience ever getting food from here. ...      qN3g1QOA
# 233626  Food was decent.  Customer Service sucks!  I o...      qN3g1QOA
# 233627  Mama's Place is definitely a go-to when you ar...      qN3g1QOA
# 233628  I order from this place on Foodler and have sa...      qN3g1QOA
# 233629  First off, Food. -4 stars-\r\nThe food is very...      qN3g1QOA
# 233630  The delivery guy was incredibly rude and late,...      qN3g1QOA
# 233631  Amazing gyros and kobobs. And their zitziki is...      qN3g1QOA
# 233632  Ok! Just ordered from Mama's Place for the fir...      qN3g1QOA
# 233633  I've had their Gyro sandwich twice for takeout...      qN3g1QOA
# 233634  Really great value. Ordered delivery with a sp...      qN3g1QOA
# 233635  Just had the worst experience placing an order...      qN3g1QOA
# 233636  Ordered from Foodler and it took almost two ho...      qN3g1QOA
# 233637  Mama's Place has literally been the worst plac...      qN3g1QOA
# 233638  I've eaten here twice. \r\n\r\nThe first time ...      qN3g1QOA
# 233639  Unfortunately this is not a review about their...      qN3g1QOA
# 233640  We ordered take out for a late night session o...      qN3g1QOA
# 233641  I ordered through Foodler and got a Barbeque b...      qN3g1QOA
# 233642  First let me say is never understand how peopl...      qN3g1QOA
# 233643  The food's very good.  Their pita and rice are...      qN3g1QOA
# 233644  Mama's Place is exactly what the name implies ...      qN3g1QOA
# 233645  Food was soggy and cold by the time I got it a...      qN3g1QOA
# 233646  I had delivery. The chicken kabob was tasty, t...      qN3g1QOA
#
# [233647 rows x 5 columns]

# %% [markdown]
# For each inspection, find any Yelp reviews written in the past year, take the mean of the numerical ratings, and compile (i.e. concatenate) the text:

# %%
pd.options.mode.chained_assignment = None

violations['delay'] = nan
    
for row in range(len(violations)):
    ri = violations.restaurant_id.iloc[row]
    t = violations.date.iloc[row]
    tlast = violations[(violations.date <= t - timedelta(days = 1)) & (violations.restaurant_id == ri)].date.max()
    violations['delay'].iloc[row] = t - tlast
    r = reviews[
        (reviews.restaurant_id == ri) &
        (reviews.date <= t - timedelta(days = 1)) &
        (reviews.date >= t - timedelta(days = 365))
    ]
    violations['rating'].iloc[row] = r.stars.mean()
    violations['reviews'].iloc[row] = r['text'].str.cat(sep=' ')
    
        
violations['delay'] = (violations.delay) / (timedelta(days=1))
violations['delay'] = violations.delay.astype(float)

# %%
violations
# Out:
#             date restaurant_id   *  **  ***  \
# 15836 2011-08-01      NbE1Bk3J   8   1    0
# 1401  2011-08-01      7RO5vjEq   7   1    0
# 25218 2011-08-01      V430D43B   1   0    2
# 34217 2011-08-01      Y1EmaVEw   7   0    1
# 27586 2011-08-01      6Wo2Nyo9  11   2    1
# 33235 2011-08-01      8x3zgYok   2   0    1
# 6368  2011-08-01      8x3zx2Ok   5   0    2
# 21033 2011-08-01      qN3gvnEA   5   0    1
# 21523 2011-08-01      VpoG57Er   1   0    0
# 6157  2011-08-01      dj3dlN39   1   0    2
# 3004  2011-08-01      8x3zQZEk   4   1    1
# 355   2011-08-01      nkOvRxOB   2   0    2
# 21824 2011-08-01      8xEx44E0   5   1    2
# 24574 2011-08-01      8x3zdNOk   2   1    0
# 32211 2011-08-01      6K3lj6Oz   3   0    0
# 21858 2011-08-01      KAoK283g   5   1    4
# 10741 2011-08-01      ZBEn6pEY   1   0    1
# 31048 2011-08-01      dj3d57o9   8   1    0
# 10989 2011-08-01      dj3dqNo9   3   1    0
# 7354  2011-08-02      N6OkkGOx   5   1    0
# 19115 2011-08-02      p038ZvOm   0   0    0
# 5379  2011-08-02      v5oJMA3B   4   0    0
# 34620 2011-08-02      Pk3wga3d   3   0    3
# 6858  2011-08-02      ydEjW23W   1   0    2
# 1267  2011-08-02      ZBEn02oY   4   0    0
# 6716  2011-08-02      JBEy6m38   2   0    3
# 21940 2011-08-02      rNo6gqO6   1   0    0
# 33447 2011-08-02      ZBEnraEY   3   0    1
# 8305  2011-08-02      7RO5wd3q   5   2    0
# 23759 2011-08-02      9JoP47o8   6   0    0
# ...          ...           ...  ..  ..  ...
# 11296 2015-06-23      ydEjQ2OW   6   1    0
# 27508 2015-06-23      B1oXMDOV   6   0    2
# 21326 2015-06-23      WeEere3a   3   0    0
# 14713 2015-06-23      7RO56XEq   3   0    1
# 1479  2015-06-23      geEVRzEz   1   1    1
# 23630 2015-06-23      p038De3m   2   0    0
# 12454 2015-06-23      nkOvZZOB   2   0    0
# 765   2015-06-23      ydEjeOW0   4   1    0
# 18310 2015-06-23      we395l3k   2   0    0
# 2472  2015-06-23      xWoYGMEK   3   0    0
# 26525 2015-06-24      rJoQdL3V   4   0    0
# 17962 2015-06-24      6K3lB8Oz   2   0    1
# 33974 2015-06-24      nkOvWxEB   7   2    0
# 27806 2015-06-24      JBEyamE8   8   1    1
# 14030 2015-06-24      qN3gAYOA   5   1    3
# 2423  2015-06-24      XJ3r1bER   4   0    1
# 7875  2015-06-24      Y1EmNn3w   6   1    0
# 35221 2015-06-24      m0oW02OG   5   0    0
# 22714 2015-06-24      6K3lZqOz   0   0    2
# 19870 2015-06-24      we39KlOk   6   2    4
# 1924  2015-06-24      B1oX66EV   2   1    3
# 14533 2015-06-24      1m3MbpoB   5   0    1
# 5337  2015-06-24      njoZqQ3r   8   1    0
# 33931 2015-06-25      nkOv473B   0   0    0
# 20585 2015-06-25      Y1EmxWOw   6   0    3
# 30857 2015-06-25      8gOqY0O2   1   0    0
# 20620 2015-06-25      dj3dBLO9  13   1    3
# 24516 2015-06-25      eVOBda3j  11   0    1
# 33342 2015-06-25      nkOvkaEB   5   1    0
# 35387 2015-06-25      m0oWY1EG   9   0    3
#
#                                      name  \
# 15836                 Crazy Dough's Pizza
# 1401                        Arirang House
# 25218                 The Florentine Cafe
# 34217                        Q Restaurant
# 27586                              Caribe
# 33235                         Au Bon Pain
# 6368         Boston Marriott Copley Place
# 21033                         Taiwan Café
# 21523                Papa Gino's Pizzeria
# 6157                         Sakkio Japan
# 3004                        Beijing Taste
# 355                            Sushi Time
# 21824                         Mul's Diner
# 24574                         China House
# 32211            Gennaro's 5 North Square
# 21858                  The Breakfast Club
# 10741                      Dunkin' Donuts
# 31048                        Quic Pic BBQ
# 10989  Charley's Eating & Drinking Saloon
# 7354                  Pan Thai Restaurant
# 19115                    The Bus Stop Pub
# 5379                           Rome Pizza
# 34620                     Beantown Hoagie
# 6858                              Sorelle
# 1267          Anthony's Pier 4 Restaurant
# 6716                   Boston Kebab House
# 21940               Chacho's Pizza & Subs
# 33447                     Emack & Bolio's
# 8305                     The Barking Crab
# 23759          Beacon Hill Hotel & Bistro
# ...                                   ...
# 11296    Carlo's Market & Cold Cut Center
# 27508                     JP Seafood Cafe
# 21326          JJ Foley's Fireside Tavern
# 14713                       Esperia Grill
# 1479                         Twin DO-Nuts
# 23630                     Boston Shawarma
# 12454                             No Name
# 765                         Alex's Chimis
# 18310               The Charlesmark Hotel
# 2472                    Boston Chowda Co.
# 26525                          Jae's Cafe
# 17962                            Saraceno
# 33974                  Stats Bar & Grille
# 27806                             Salsa's
# 14030                               Douzo
# 2423                           M & M Ribs
# 7875                Village Sushi & Grill
# 35221                          Applebee's
# 22714                      Scollay Square
# 19870                    Saray Restaurant
# 1924                Cookin' Cafe & Grille
# 14533                      Gigi Gelateria
# 5337                                 Mare
# 33931                 Monumental Cupcakes
# 20585                Blue Star Restaurant
# 30857              Chipotle Mexican Grill
# 20620                           The Point
# 24516                   Il Panino Express
# 33342                  Pho Hoa Restaurant
# 35387                    Imperial Kitchen
#
#                                                  reviews    rating   latitude  \
# 15836  Manger une pizza a pas chers c est la place qu...  3.750000  42.346810
# 1401   Buffet joints aren't usually where you go to g...  2.125000  42.346246
# 25218  Was told it was a 5 min wait for a table. They...  3.289474  42.364263
# 34217  Dropped in with a friend during one of their s...  3.464286  42.351813
# 27586                                                          NaN  42.315208
# 33235  I like Au Bon Pain very much.  Whether it's th...  1.833333  42.349664
# 6368   We stayed at this hotel for 3 nights for the f...  3.523810  42.347022
# 21033  It's a love/hate relationship. There are times...  3.629630  42.351503
# 21523                                                          NaN  42.255668
# 6157   Get the teriyaki chicken with EXTRA chicken!  ...  4.000000  42.355682
# 3004   Not again...why is it impossible to find good ...  2.000000  42.382491
# 355    For a small sushi bar/kiosk that is located in...  3.500000  42.355849
# 21824  After much waiting I had a chance to try Mul's...  4.083333  42.341819
# 24574  Pros:\r\n- cheap\r\n- delivers\r\n- nice peopl...  2.600000  42.364228
# 32211  A good restaurant should maintain it's standar...  3.500000  42.364030
# 21858  BEST BREAKFAST/BRUNCH IN BOSTON..Let me put it...  4.071429  42.363163
# 10741  I really like this Dunkin Donuts because it is...  4.000000  42.362126
# 31048  taste is very good. Economic price but valuabl...  4.125000  42.351534
# 10989  I cam here twice during my stay in Boston.  Fe...  3.826087  42.348968
# 7354   Just ate here, and I would echo the feelings o...  3.444444  42.343409
# 19115  The Bus Stop is likeable and consistent.  The ...  3.000000  42.363345
# 5379   I wish I could give other rating symbols in ye...  2.000000  42.346646
# 34620  I enjoyed my Panini from this new sandwich sho...  2.875000  42.358127
# 6858   Um, not so much.  \r\n\r\nI liked you at first...  3.000000  42.371362
# 1267   Was glad I made a reservation, since others wh...  2.684211  42.353376
# 6716   When I need a great salad full of veggies and ...  4.187500  42.358130
# 21940  The best slice for the price! AND NOW THEY DEL...  4.000000  42.332249
# 33447  Emack, you rock.  I mean, let's be honest here...  4.500000  42.371488
# 8305   My time in Miami taught me to find the best pl...  2.931034  42.353930
# 23759  This is one of my favorite places in Boston fo...  3.192308  42.356802
# ...                                                  ...       ...        ...
# 11296  I was not impressed with my sandwich this past...  4.444444  42.382556
# 27508  This place is so much better than its name sug...  3.972222  42.310855
# 21326  This place wreaks like a mixture of piss and w...  1.000000  42.299192
# 14713  I love this place they have great authentic fo...  4.575758  42.349081
# 1479   Gotta love Twin Donuts. Small business. Mad ch...  4.189189  42.353527
# 23630  So delicious it's silly how little you pay for...  4.472222  42.341130
# 12454  No Name had been recommended to me by a co-wor...  2.257732  42.351281
# 765    Great authentic Dominican food! Don't really g...  4.200000  42.322387
# 18310  Two nights in a row when the server/bartender ...  3.473684  42.350079
# 2472   Good chowder soup! I liked the taste and it wa...  3.870130  42.360157
# 26525  Great sushi... different styles of asian food:...  3.941176  42.341947
# 17962  Definitely check out this restaurant. Saraceno...  3.842105  42.363961
# 33974  I was visiting Boston a few weeks ago\r\nfor m...  3.285714  42.335699
# 27806  I'll start with the good:  service was prompt,...  2.590909  42.335054
# 14030  Went here on Father's Day for lunch.  The serv...  3.690909  42.347109
# 2423   What a great find!  Stopped by for food truck ...  4.333333  42.329666
# 7875   Worst sushi I've had in years. The rice was fa...  3.461538  42.286553
# 35221  First time @ this location. They bombed it. Wa...  2.625000  42.326007
# 22714  Big fan of the atmosphere, cocktails, and vari...  3.563636  42.358080
# 19870  I was very excited to try out this place, but ...  3.050000  42.352265
# 1924   If you're hungry, don't want burnt food, and h...  2.454545  42.351820
# 14533  Gel lato crap..!   If you see this place just ...  2.277778  42.363697
# 5337   Great food lacking service. I went with the pa...  4.052632  42.363272
# 33931  Thanks to the team at Monumental for the most ...  4.333333  42.308304
# 20585  What has happened to this place?   When I live...  3.333333  42.286467
# 30857  I've been coming here for months and had no pr...  3.235294  42.344920
# 20620  Went for lunch.  Good casual food, good beer, ...  3.900000  42.361715
# 24516                                                          NaN  42.363673
# 33342  Pho Hoa is known for it's tasty broth and I co...  3.272727  42.303899
# 35387  This  food is flavorless  there were no vegeta...  1.000000  42.285934
#
#        longitude  delay
# 15836 -71.088960    NaN
# 1401  -71.087049    NaN
# 25218 -71.053833    NaN
# 34217 -71.062679    NaN
# 27586 -71.066018    NaN
# 33235 -71.070235    NaN
# 6368  -71.079289    NaN
# 21033 -71.060239    NaN
# 21523 -71.123935    NaN
# 6157  -71.060278    NaN
# 3004  -71.079354    NaN
# 355   -71.060340    NaN
# 21824 -71.055742    NaN
# 24574 -71.053931    NaN
# 32211 -71.053506    NaN
# 21858 -71.133545    NaN
# 10741 -71.130381    NaN
# 31048 -71.060727    NaN
# 10989 -71.084284    NaN
# 7354  -71.086696    NaN
# 19115 -71.132681    NaN
# 5379  -71.068810    NaN
# 34620 -71.054912    NaN
# 6858  -71.061000    NaN
# 1267  -71.041540    NaN
# 6716  -71.055457    NaN
# 21940 -71.099284    NaN
# 33447 -71.061256    NaN
# 8305  -71.048629    NaN
# 23759 -71.069615    NaN
# ...          ...    ...
# 11296 -71.018407  274.0
# 27508 -71.114427  154.0
# 21326 -71.114045  182.0
# 14713 -71.152886  320.0
# 1479  -71.137959    7.0
# 23630 -71.087780  110.0
# 12454 -71.037663  124.0
# 765   -71.107601   14.0
# 18310 -71.078610  508.0
# 2472  -71.055152    8.0
# 26525 -71.079846   13.0
# 17962 -71.054529    7.0
# 33974 -71.045196   15.0
# 27806 -71.046321  363.0
# 14030 -71.075589    1.0
# 2423  -71.074928  442.0
# 7875  -71.130025  166.0
# 35221 -71.063185   14.0
# 22714 -71.062559   42.0
# 19870 -71.124072  329.0
# 1924  -71.124296  321.0
# 14533 -71.054601    7.0
# 5337  -71.054101    7.0
# 33931 -71.115365  160.0
# 20585 -71.130419  134.0
# 30857 -71.100947    7.0
# 20620 -71.056963    7.0
# 24516 -71.054781    7.0
# 33342 -71.059241  120.0
# 35387 -71.129344  134.0
#
# [17557 rows x 11 columns]

# %% [markdown]
# Create and try to optimize the parameters for a naive Bayes classifier:

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cross_validation import train_test_split
from sklearn.naive_bayes import MultinomialNB

def make_xy(violations, vectorizer=None):
    if vectorizer is None:
        vectorizer = CountVectorizer()
    X = vectorizer.fit_transform(violations.reviews)
    X = X.tocsc()
    y = (violations['*'] + violations['**'] + violations['***'] > 0).values.astype(np.int)
    return X, y

# %%
violations = violations[violations.delay > 45]

bestscore = -1
bestmd = -1
bestMd = -1
besta = -1
for md in (0.0, 0.01, 0.05, 0.1, 0.2, 0.4):
    for Md in (0.5, 0.6, 0.7, 0.8, 0.9, 1.0):
        for a in (1, 5, 8, 12, 20):

            X, y = make_xy(violations, vectorizer=CountVectorizer(min_df = md, max_df = Md, ngram_range = (1,1)))

            clf = MultinomialNB(alpha = a)
            Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, train_size=.8)
            clf.fit(Xtrain, ytrain)
            thisscore = clf.score(Xtest, ytest)
            print(
                'min: ' + str(md) +
                ', max: ' + str(Md) +
                ', alpha: ' + str(a) +
                ', train: ' + str(clf.score(Xtrain, ytrain)) +
                ', test: ' + str(thisscore)
            )
            if thisscore > bestscore:
                bestscore = thisscore
                bestmd = md
                bestMd = Md
                besta = a
# Out:
# min: 0.0, max: 0.5, alpha: 1, train: 0.746854403835, test: 0.599401197605
# min: 0.0, max: 0.5, alpha: 5, train: 0.688735769922, test: 0.625748502994
# min: 0.0, max: 0.5, alpha: 8, train: 0.655931695626, test: 0.635928143713
# min: 0.0, max: 0.5, alpha: 12, train: 0.645146794488, test: 0.641916167665
# min: 0.0, max: 0.5, alpha: 20, train: 0.639604553625, test: 0.631736526946
# min: 0.0, max: 0.6, alpha: 1, train: 0.750599161174, test: 0.607784431138
# min: 0.0, max: 0.6, alpha: 5, train: 0.686488915518, test: 0.651497005988
# min: 0.0, max: 0.6, alpha: 8, train: 0.657878969443, test: 0.648502994012
# min: 0.0, max: 0.6, alpha: 12, train: 0.643199520671, test: 0.641317365269
# min: 0.0, max: 0.6, alpha: 20, train: 0.635260635111, test: 0.650299401198
# min: 0.0, max: 0.7, alpha: 1, train: 0.746554823247, test: 0.578443113772
# min: 0.0, max: 0.7, alpha: 5, train: 0.686788496105, test: 0.631137724551
# min: 0.0, max: 0.7, alpha: 8, train: 0.663720790893, test: 0.634730538922
# min: 0.0, max: 0.7, alpha: 12, train: 0.642150988616, test: 0.643113772455
# min: 0.0, max: 0.7, alpha: 20, train: 0.638256440983, test: 0.62994011976
# min: 0.0, max: 0.8, alpha: 1, train: 0.738615937687, test: 0.592215568862
# min: 0.0, max: 0.8, alpha: 5, train: 0.690982624326, test: 0.632934131737
# min: 0.0, max: 0.8, alpha: 8, train: 0.661024565608, test: 0.630538922156
# min: 0.0, max: 0.8, alpha: 12, train: 0.648442180947, test: 0.622754491018
# min: 0.0, max: 0.8, alpha: 20, train: 0.637956860395, test: 0.633532934132
# min: 0.0, max: 0.9, alpha: 1, train: 0.748502097064, test: 0.590419161677
# min: 0.0, max: 0.9, alpha: 5, train: 0.687088076693, test: 0.636526946108
# min: 0.0, max: 0.9, alpha: 8, train: 0.658627920911, test: 0.649700598802
# min: 0.0, max: 0.9, alpha: 12, train: 0.645146794488, test: 0.626347305389
# min: 0.0, max: 0.9, alpha: 20, train: 0.633163571001, test: 0.649700598802
# min: 0.0, max: 1.0, alpha: 1, train: 0.740563211504, test: 0.59880239521
# min: 0.0, max: 1.0, alpha: 5, train: 0.687687237867, test: 0.618562874251
# min: 0.0, max: 1.0, alpha: 8, train: 0.653984421809, test: 0.654491017964
# min: 0.0, max: 1.0, alpha: 12, train: 0.643948472139, test: 0.640119760479
# min: 0.0, max: 1.0, alpha: 20, train: 0.635710005992, test: 0.641916167665
# min: 0.01, max: 0.5, alpha: 1, train: 0.62103055722, test: 0.571856287425
# min: 0.01, max: 0.5, alpha: 5, train: 0.619982025165, test: 0.567065868263
# min: 0.01, max: 0.5, alpha: 8, train: 0.610994607549, test: 0.552095808383
# min: 0.01, max: 0.5, alpha: 12, train: 0.622079089275, test: 0.601796407186
# min: 0.01, max: 0.5, alpha: 20, train: 0.617735170761, test: 0.589221556886
# min: 0.01, max: 0.6, alpha: 1, train: 0.620880766926, test: 0.582035928144
# min: 0.01, max: 0.6, alpha: 5, train: 0.614739364889, test: 0.558083832335
# min: 0.01, max: 0.6, alpha: 8, train: 0.613690832834, test: 0.574850299401
# min: 0.01, max: 0.6, alpha: 12, train: 0.616836428999, test: 0.55748502994
# min: 0.01, max: 0.6, alpha: 20, train: 0.622977831037, test: 0.576047904192
# min: 0.01, max: 0.7, alpha: 1, train: 0.621180347513, test: 0.608383233533
# min: 0.01, max: 0.7, alpha: 5, train: 0.619682444578, test: 0.568263473054
# min: 0.01, max: 0.7, alpha: 8, train: 0.604853205512, test: 0.561676646707
# min: 0.01, max: 0.7, alpha: 12, train: 0.612043139605, test: 0.58502994012
# min: 0.01, max: 0.7, alpha: 20, train: 0.627171959257, test: 0.60119760479
# min: 0.01, max: 0.8, alpha: 1, train: 0.619682444578, test: 0.578443113772
# min: 0.01, max: 0.8, alpha: 5, train: 0.616237267825, test: 0.588622754491
# min: 0.01, max: 0.8, alpha: 8, train: 0.623427201917, test: 0.576646706587
# min: 0.01, max: 0.8, alpha: 12, train: 0.617735170761, test: 0.6
# min: 0.01, max: 0.8, alpha: 20, train: 0.636309167166, test: 0.573652694611
# min: 0.01, max: 0.9, alpha: 1, train: 0.615338526064, test: 0.581437125749
# min: 0.01, max: 0.9, alpha: 5, train: 0.606201318155, test: 0.589221556886
# min: 0.01, max: 0.9, alpha: 8, train: 0.61728579988, test: 0.580239520958
# min: 0.01, max: 0.9, alpha: 12, train: 0.612492510485, test: 0.594610778443
# min: 0.01, max: 0.9, alpha: 20, train: 0.628370281606, test: 0.588023952096
# min: 0.01, max: 1.0, alpha: 1, train: 0.617884961055, test: 0.563473053892
# min: 0.01, max: 1.0, alpha: 5, train: 0.620281605752, test: 0.567065868263
# min: 0.01, max: 1.0, alpha: 8, train: 0.603954463751, test: 0.570658682635
# min: 0.01, max: 1.0, alpha: 12, train: 0.615338526064, test: 0.591616766467
# min: 0.01, max: 1.0, alpha: 20, train: 0.612492510485, test: 0.592814371257
# min: 0.05, max: 0.5, alpha: 1, train: 0.599310964649, test: 0.566467065868
# min: 0.05, max: 0.5, alpha: 5, train: 0.602156980228, test: 0.582634730539
# min: 0.05, max: 0.5, alpha: 8, train: 0.592121030557, test: 0.564670658683
# min: 0.05, max: 0.5, alpha: 12, train: 0.609496704614, test: 0.573053892216
# min: 0.05, max: 0.5, alpha: 20, train: 0.594667465548, test: 0.568263473054
# min: 0.05, max: 0.6, alpha: 1, train: 0.602756141402, test: 0.595209580838
# min: 0.05, max: 0.6, alpha: 5, train: 0.596914319952, test: 0.565868263473
# min: 0.05, max: 0.6, alpha: 8, train: 0.597813061714, test: 0.58622754491
# min: 0.05, max: 0.6, alpha: 12, train: 0.592570401438, test: 0.578443113772
# min: 0.05, max: 0.6, alpha: 20, train: 0.614889155183, test: 0.570658682635
# min: 0.05, max: 0.7, alpha: 1, train: 0.598562013182, test: 0.57125748503
# min: 0.05, max: 0.7, alpha: 5, train: 0.607849011384, test: 0.609580838323
# min: 0.05, max: 0.7, alpha: 8, train: 0.595416417016, test: 0.581437125749
# min: 0.05, max: 0.7, alpha: 12, train: 0.59391851408, test: 0.556886227545
# min: 0.05, max: 0.7, alpha: 20, train: 0.603654883164, test: 0.586826347305
# min: 0.05, max: 0.8, alpha: 1, train: 0.595266626723, test: 0.577844311377
# min: 0.05, max: 0.8, alpha: 5, train: 0.605901737567, test: 0.584431137725
# min: 0.05, max: 0.8, alpha: 8, train: 0.608597962852, test: 0.579041916168
# min: 0.05, max: 0.8, alpha: 12, train: 0.600209706411, test: 0.574251497006
# min: 0.05, max: 0.8, alpha: 20, train: 0.606201318155, test: 0.58502994012
# min: 0.05, max: 0.9, alpha: 1, train: 0.598711803475, test: 0.605988023952
# min: 0.05, max: 0.9, alpha: 5, train: 0.608448172558, test: 0.592814371257
# min: 0.05, max: 0.9, alpha: 8, train: 0.610695026962, test: 0.600598802395
# min: 0.05, max: 0.9, alpha: 12, train: 0.605152786099, test: 0.590419161677
# min: 0.05, max: 0.9, alpha: 20, train: 0.600059916117, test: 0.573652694611
# min: 0.05, max: 1.0, alpha: 1, train: 0.606650689035, test: 0.608982035928
# min: 0.05, max: 1.0, alpha: 5, train: 0.597513481126, test: 0.591616766467
# min: 0.05, max: 1.0, alpha: 8, train: 0.611893349311, test: 0.6
# min: 0.05, max: 1.0, alpha: 12, train: 0.599910125824, test: 0.592814371257
# min: 0.05, max: 1.0, alpha: 20, train: 0.604254044338, test: 0.584431137725
# min: 0.1, max: 0.5, alpha: 1, train: 0.601857399641, test: 0.597604790419
# min: 0.1, max: 0.5, alpha: 5, train: 0.609946075494, test: 0.565868263473
# min: 0.1, max: 0.5, alpha: 8, train: 0.604553624925, test: 0.553892215569
# min: 0.1, max: 0.5, alpha: 12, train: 0.589874176153, test: 0.582035928144
# min: 0.1, max: 0.5, alpha: 20, train: 0.597363690833, test: 0.58622754491
# min: 0.1, max: 0.6, alpha: 1, train: 0.602306770521, test: 0.607185628743
# min: 0.1, max: 0.6, alpha: 5, train: 0.604104254044, test: 0.57245508982
# min: 0.1, max: 0.6, alpha: 8, train: 0.597363690833, test: 0.579640718563
# min: 0.1, max: 0.6, alpha: 12, train: 0.595416417016, test: 0.573053892216
# min: 0.1, max: 0.6, alpha: 20, train: 0.588675853805, test: 0.57005988024
# min: 0.1, max: 0.7, alpha: 1, train: 0.602306770521, test: 0.606586826347
# min: 0.1, max: 0.7, alpha: 5, train: 0.587028160575, test: 0.602994011976
# min: 0.1, max: 0.7, alpha: 8, train: 0.5934691432, test: 0.560479041916
# min: 0.1, max: 0.7, alpha: 12, train: 0.60140802876, test: 0.584431137725
# min: 0.1, max: 0.7, alpha: 20, train: 0.595116836429, test: 0.583233532934
# min: 0.1, max: 0.8, alpha: 1, train: 0.600209706411, test: 0.587425149701
# min: 0.1, max: 0.8, alpha: 5, train: 0.597213900539, test: 0.583233532934
# min: 0.1, max: 0.8, alpha: 8, train: 0.599161174356, test: 0.573652694611
# min: 0.1, max: 0.8, alpha: 12, train: 0.606051527861, test: 0.578443113772
# min: 0.1, max: 0.8, alpha: 20, train: 0.600659077292, test: 0.582634730539
# min: 0.1, max: 0.9, alpha: 1, train: 0.60769922109, test: 0.579041916168
# min: 0.1, max: 0.9, alpha: 5, train: 0.60350509287, test: 0.604790419162
# min: 0.1, max: 0.9, alpha: 8, train: 0.598711803475, test: 0.588023952096
# min: 0.1, max: 0.9, alpha: 12, train: 0.597363690833, test: 0.583233532934
# min: 0.1, max: 0.9, alpha: 20, train: 0.598262432594, test: 0.58622754491
# min: 0.1, max: 1.0, alpha: 1, train: 0.599610545237, test: 0.598203592814
# min: 0.1, max: 1.0, alpha: 5, train: 0.611893349311, test: 0.580838323353
# min: 0.1, max: 1.0, alpha: 8, train: 0.596914319952, test: 0.580838323353
# min: 0.1, max: 1.0, alpha: 12, train: 0.602156980228, test: 0.585628742515
# min: 0.1, max: 1.0, alpha: 20, train: 0.596614739365, test: 0.581437125749
# min: 0.2, max: 0.5, alpha: 1, train: 0.597813061714, test: 0.6
# min: 0.2, max: 0.5, alpha: 5, train: 0.596165368484, test: 0.579041916168
# min: 0.2, max: 0.5, alpha: 8, train: 0.599610545237, test: 0.594011976048
# min: 0.2, max: 0.5, alpha: 12, train: 0.587028160575, test: 0.605988023952
# min: 0.2, max: 0.5, alpha: 20, train: 0.594068304374, test: 0.592814371257
# min: 0.2, max: 0.6, alpha: 1, train: 0.596914319952, test: 0.573652694611
# min: 0.2, max: 0.6, alpha: 5, train: 0.595116836429, test: 0.587425149701
# min: 0.2, max: 0.6, alpha: 8, train: 0.597513481126, test: 0.604191616766
# min: 0.2, max: 0.6, alpha: 12, train: 0.599460754943, test: 0.580239520958
# min: 0.2, max: 0.6, alpha: 20, train: 0.595116836429, test: 0.58622754491
# min: 0.2, max: 0.7, alpha: 1, train: 0.596015578191, test: 0.58622754491
# min: 0.2, max: 0.7, alpha: 5, train: 0.594967046135, test: 0.562275449102
# min: 0.2, max: 0.7, alpha: 8, train: 0.591971240264, test: 0.598203592814
# min: 0.2, max: 0.7, alpha: 12, train: 0.596764529658, test: 0.555688622754
# min: 0.2, max: 0.7, alpha: 20, train: 0.594817255842, test: 0.598203592814
# min: 0.2, max: 0.8, alpha: 1, train: 0.597513481126, test: 0.604790419162
# min: 0.2, max: 0.8, alpha: 5, train: 0.591222288796, test: 0.589221556886
# min: 0.2, max: 0.8, alpha: 8, train: 0.603954463751, test: 0.602395209581
# min: 0.2, max: 0.8, alpha: 12, train: 0.590023966447, test: 0.576646706587
# min: 0.2, max: 0.8, alpha: 20, train: 0.592720191732, test: 0.593413173653
# min: 0.2, max: 0.9, alpha: 1, train: 0.602007189934, test: 0.575449101796
# min: 0.2, max: 0.9, alpha: 5, train: 0.59556620731, test: 0.601796407186
# min: 0.2, max: 0.9, alpha: 8, train: 0.597513481126, test: 0.606586826347
# min: 0.2, max: 0.9, alpha: 12, train: 0.602007189934, test: 0.582035928144
# min: 0.2, max: 0.9, alpha: 20, train: 0.601108448173, test: 0.57005988024
# min: 0.2, max: 1.0, alpha: 1, train: 0.598562013182, test: 0.581437125749
# min: 0.2, max: 1.0, alpha: 5, train: 0.595865787897, test: 0.580239520958
# min: 0.2, max: 1.0, alpha: 8, train: 0.590922708209, test: 0.595209580838
# min: 0.2, max: 1.0, alpha: 12, train: 0.596614739365, test: 0.551497005988
# min: 0.2, max: 1.0, alpha: 20, train: 0.593019772319, test: 0.580838323353
# min: 0.4, max: 0.5, alpha: 1, train: 0.5934691432, test: 0.608982035928
# min: 0.4, max: 0.5, alpha: 5, train: 0.591072498502, test: 0.602395209581
# min: 0.4, max: 0.5, alpha: 8, train: 0.602306770521, test: 0.567664670659
# min: 0.4, max: 0.5, alpha: 12, train: 0.594218094667, test: 0.599401197605
# min: 0.4, max: 0.5, alpha: 20, train: 0.594068304374, test: 0.601796407186
# min: 0.4, max: 0.6, alpha: 1, train: 0.592570401438, test: 0.611377245509
# min: 0.4, max: 0.6, alpha: 5, train: 0.598861593769, test: 0.594610778443
# min: 0.4, max: 0.6, alpha: 8, train: 0.590772917915, test: 0.589820359281
# min: 0.4, max: 0.6, alpha: 12, train: 0.588825644098, test: 0.594610778443
# min: 0.4, max: 0.6, alpha: 20, train: 0.597064110246, test: 0.588023952096
# min: 0.4, max: 0.7, alpha: 1, train: 0.590772917915, test: 0.6
# min: 0.4, max: 0.7, alpha: 5, train: 0.592869982025, test: 0.602395209581
# min: 0.4, max: 0.7, alpha: 8, train: 0.603205512283, test: 0.573652694611
# min: 0.4, max: 0.7, alpha: 12, train: 0.595715997603, test: 0.582634730539
# min: 0.4, max: 0.7, alpha: 20, train: 0.594517675255, test: 0.588023952096
# min: 0.4, max: 0.8, alpha: 1, train: 0.595266626723, test: 0.597005988024
# min: 0.4, max: 0.8, alpha: 5, train: 0.5934691432, test: 0.584431137725
# min: 0.4, max: 0.8, alpha: 8, train: 0.600659077292, test: 0.588622754491
# min: 0.4, max: 0.8, alpha: 12, train: 0.589424805273, test: 0.570658682635
# min: 0.4, max: 0.8, alpha: 20, train: 0.597064110246, test: 0.591017964072
# min: 0.4, max: 0.9, alpha: 1, train: 0.595715997603, test: 0.571856287425
# min: 0.4, max: 0.9, alpha: 5, train: 0.594817255842, test: 0.589221556886
# min: 0.4, max: 0.9, alpha: 8, train: 0.598562013182, test: 0.591616766467
# min: 0.4, max: 0.9, alpha: 12, train: 0.599011384062, test: 0.58502994012
# min: 0.4, max: 0.9, alpha: 20, train: 0.592570401438, test: 0.591017964072
# min: 0.4, max: 1.0, alpha: 1, train: 0.593019772319, test: 0.589820359281
# min: 0.4, max: 1.0, alpha: 5, train: 0.587777112043, test: 0.585628742515
# min: 0.4, max: 1.0, alpha: 8, train: 0.598711803475, test: 0.594610778443
# min: 0.4, max: 1.0, alpha: 12, train: 0.596614739365, test: 0.579640718563
# min: 0.4, max: 1.0, alpha: 20, train: 0.59976033553, test: 0.584431137725

# %%
bestmd, bestMd, besta, bestscore
# Out:
# (0.0, 1.0, 8, 0.65449101796407183)

# %% [markdown]
# Re-create the classifier with the best parameters found (accuracy 0.654), and list some of the most predictive words:

# %%
vectorizer=CountVectorizer(min_df = 0.0, max_df = 1.0)
X, y = make_xy(violations, vectorizer)

clf = MultinomialNB(alpha = 8)
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, train_size=.8)
clf.fit(Xtrain, ytrain)
# Out:
# MultinomialNB(alpha=8, class_prior=None, fit_prior=True)

# %%
words = np.array(vectorizer.get_feature_names())

probs = np.zeros(len(words))

for i in range(len(words)):
    x = np.zeros(len(words))
    x[i] = 1
    probs[i] = clf.predict_log_proba(x.reshape(1,-1))[0,0]


ind = np.argsort(probs)

bad_words = words[ind[:30]]
good_words = words[ind[-30:]]

bad_prob = probs[ind[:30]]
good_prob = probs[ind[-30:]]

print( "Bad words\t     P(fail | word)")
for w, p in zip(bad_words, bad_prob):
    print( "%20s" % w, "%0.2f" % (1 - np.exp(p)))
    
print( "Good words\t     P(fail | word)")
for w, p in zip(good_words, good_prob):
    print( "%20s" % w, "%0.2f" % (1 - np.exp(p)))
# Out:
# Bad words	     P(fail | word)
#              trident 0.97
#                doyle 0.96
#               sonsie 0.96
#            bookstore 0.96
#              penguin 0.95
#              kashmir 0.95
#               durgin 0.95
#                 masa 0.92
#                 olio 0.92
#               grotto 0.92
#              orinoco 0.91
#               haggis 0.91
#                aglio 0.91
#             merengue 0.90
#            dominican 0.90
#                 frik 0.89
#               fleuri 0.88
#             bleacher 0.88
#              trolley 0.88
#              typhoon 0.88
#                arepa 0.88
#                   5n 0.87
#               snappy 0.87
#               parker 0.87
#               barlow 0.87
#               zocalo 0.86
#                haley 0.86
#               napkin 0.86
#             scottish 0.86
#                lucia 0.86
# Good words	     P(fail | word)
#               schlow 0.23
#                 ober 0.23
#                skits 0.23
#                locke 0.22
#               lorenz 0.22
#                  ufo 0.22
#               blunch 0.22
#                avila 0.21
#              harpoon 0.21
#                  bmh 0.20
#             pretzels 0.20
#            limelight 0.20
#                canai 0.20
#                wally 0.18
#             growlers 0.18
#               improv 0.18
#                tours 0.17
#              gustavo 0.17
#               actors 0.17
#                 bina 0.17
#                 tico 0.17
#                noche 0.16
#               guides 0.15
#               tavolo 0.15
#              rivalry 0.15
#               teatro 0.14
#              growler 0.13
#                tasca 0.12
#              sibling 0.11
#              pigalle 0.06
